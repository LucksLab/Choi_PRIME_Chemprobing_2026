# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib as mpl

# Set Helvetica font globally
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = ['Helvetica']

# Optional: make sure fonts are updated
mpl.rcParams['pdf.fonttype'] = 42  # Avoids Type 3 fonts in PDF output
mpl.rcParams['ps.fonttype'] = 42

# %%
pH_kdeg_data = pd.read_csv('/Users/edricchoi/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/88_EKC_Probing_model/Manuscript/Data_elements/03_nmr_dms_degradation/NMR_data/01.046.NMR_hydrolysis_pH_dependence/pH_v_kdeg.csv')

# %%
fig, ax = plt.subplots(figsize=(3, 3))
ax.plot(pH_kdeg_data['pH'], pH_kdeg_data['lnkdeg'], marker='o', linestyle='-', color='black', markersize = 4, linewidth = 1)
ax.set_xlabel('pH')
ax.set_ylabel(r'$\ln(k_{deg})$')
plt.tight_layout()
plt.savefig('kdeg_pH_dependence.pdf')
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
