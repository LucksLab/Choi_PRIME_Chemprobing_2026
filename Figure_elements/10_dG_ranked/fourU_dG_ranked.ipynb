# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.constants as sc

# %%
fourU_dG = pd.read_csv('/Users/edricchoi/LucksLab Dropbox/LucksLab/Lucks_Lab_Papers/In_Progress/88_EKC_Probing_model/Manuscript/Data_elements/08_dG_barplots/fourU_calc_dG.csv')
fourU_wt = sorted(fourU_dG[fourU_dG['disp_name'] == '4U_wt']['dG'].values)
fourU_a8c = sorted(fourU_dG[fourU_dG['disp_name'] == '4U_a8c']['dG'].values)

fig, ax = plt.subplots(figsize=(3, 3))
ax.plot(fourU_wt, color='black', marker = 'o', linewidth=2, label='4U_wt')
ax.plot(fourU_a8c, color='darkred', marker = 'o', linewidth=2, label='4U_a8c')
ax.set_xlabel('Ranked Index')
ax.set_ylabel(r'$\Delta G_{DMS}$ (kcal/mol)')
# Out:
# Text(0, 0.5, '$\\Delta G_{DMS}$ (kcal/mol)')
