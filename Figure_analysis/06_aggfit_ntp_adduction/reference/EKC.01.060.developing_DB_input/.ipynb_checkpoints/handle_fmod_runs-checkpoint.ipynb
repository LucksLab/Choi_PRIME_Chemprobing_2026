# %%
import sqlite3
import glob
import pandas as pd
import traceback

# %%
def extract_info_from_log(log_file, sample_name, run0420 = None):
    """
    Extracts information from a ShapeMapper log file.

    Parameters:
        log_file (str): Path to the ShapeMapper log file.
        sample_name (str): Name of the sample to check against the R1 file.

    Returns:
        tuple: Contains the following elements:
            - run_datetime (str): The datetime when the ShapeMapper run started.
            - version (str): The version of ShapeMapper used.
            - r1_file (str): The R1 file used in the run.
            - untreated (int): Indicates if the sample was untreated (1 if untreated, 0 otherwise).
            - denatured (int): Indicates if the sample was denatured (1 if denatured, 0 otherwise).
            - sample_check (bool): Indicates if the sample name matches the R1 file.
    """

    with open(log_file) as f:
        lines = f.readlines()

    # find all lines containing "Started ShapeMapper" and get index of most recent one
    detect_shapemapper_runs = [i for i, line in enumerate(lines) if 'Started ShapeMapper' in line]
    assert len(detect_shapemapper_runs) > 0, 'No ShapeMapper runs detected in log file'

    most_recent_run = detect_shapemapper_runs[-1]
    lines = lines[most_recent_run:]

    # check shapemapper success
    run_completed = [i for i, line in enumerate(lines) if ('ShapeMapper run completed' in line) or ('ShapeMapper run successfully completed' in line)]
    if len(run_completed) == 0:
        print(f'ShapeMapper run not completed successfully in log file: {log_file}')
        return None

    #print(log_file)
    # extract date and version from:  "Started ShapeMapper v2.2.0 at 2023-04-22 17:19:59"
    version_date_line = lines[0]
    run_datetime = version_date_line.split(' at ')[1].rstrip()
    version = version_date_line.split(' ')[2]
    run_args = lines[2]
    assert 'args: ' in run_args, 'args line not found in log file'
    
    # get index of 'modified'
    modified_index = run_args.split(' --').index('modified')
    assert modified_index > 0, 'modified not found in run_args'

    # extract R1 file
    r1_file = run_args.split(' --')[modified_index + 1].split(' ')[-1]
    assert (r1_file is not None) or (r1_file == ''), 'R1 file not found in run_args'

    untreated = 0
    denatured = 0
    # check if untreated sample provided
    if 'untreated' in run_args.split(' --'):
        untreated_index = run_args.split(' --').index('untreated')
        untreated_r1_file = run_args.split(' --')[untreated_index + 1].split(' ')[-1]
        assert (untreated_r1_file is not None) or (untreated_r1_file == ''), 'R1 file not found in run_args'
        untreated = untreated_r1_file
    elif 'denatured' in run_args.split(' --'):
        denatured_index = run_args.split(' --').index('denatured')
        den_r1_file = run_args.split(' --')[denatured_index + 1].split(' ')[-1]
        assert (den_r1_file is not None) or (den_r1_file == ''), 'R1 file not found in run_args'
        denatured = den_r1_file

    # confirm sample_name matches r1_file
    # remove .fastq.gz from both if they exist
    if len(r1_file.split('/')) > 2:
        r1_file = r1_file.split('/')[-1]
        r1_file_check = r1_file.replace('...', '')
        sample_name_check = sample_name[:len(r1_file_check)]
        sample_check = (sample_name_check == r1_file_check)
        return run_datetime, run_args, version, r1_file, untreated, denatured, sample_check
    if r1_file.endswith('.fastq.gz'):
        r1_file_check = r1_file[:-9]
    elif r1_file.endswith('.fastq'):
        r1_file_check = r1_file[:-6]
    else:
        r1_file_check = r1_file
    if sample_name.endswith('.fastq.gz'):
        sample_name_check = sample_name[:-9]
    elif sample_name.endswith('.fastq'):
        sample_name_check = sample_name[:-6]
    else:
        sample_name_check = sample_name
    if r1_file.startswith('./'):
        r1_file_check = r1_file_check[2:]
    if sample_name_check.startswith('YYYR'):
        r1_file_check = r1_file_check[5:]
        sample_name_check = sample_name_check[5:]
    elif sample_name_check.startswith('etOH'):
        #DMS-150-WTII_S8_L001_R1_001 etOH-150-WTII_S16_L001_R1_001
        r1_file_check = '-'.join(r1_file_check.split('_')[0].split('-')[1:])
        sample_name_check = '-'.join(sample_name_check.split('_')[0].split('-')[1:])

    sample_check = (sample_name_check == r1_file_check)

    # override mistaken r1 file name
    if 'WT-33c-b-6' in r1_file_check:
        sample_check = True

    if sample_check == False:
        # try removing all underscores and compare again
        r1_file_check = r1_file_check.replace('_', '')
        sample_name_check = sample_name_check.replace('_', '')
        sample_check = (sample_name_check == r1_file_check)
        if sample_check == False:
            print(r1_file_check, sample_name_check)

    if run0420:
        name_index = run_args.split(' --')[1]
        assert 'name' in name_index, 'name not found in run_args'
        name_check = name_index.split(' ')[-1]
        sample_check = name_check in sample_name
        if sample_check:
            print('Rechecking on name successful')
        else:
            print(r1_file_check, sample_name_check)

    return run_datetime, run_args, version, r1_file, untreated, denatured, sample_check

def fetch_s_id(db_file, sample_name):
    """
    Fetches the ID of a sample from the sequencing_samples table.

    Parameters:
        db_file (str): Path to the database file.
        sample_name (str): Name of the sample to fetch the ID for.

    Returns:
        int: The ID of the sample.
    """
    
    conn = sqlite3.connect(db_file)
    c = conn.cursor()
    c.execute('SELECT id FROM sequencing_samples WHERE sample_name = ?', (sample_name,))
    result = c.fetchall()  # Fetch only one row
    conn.close()

    if result is None:
        raise ValueError(f"No sample found with name: {sample_name}")
    elif len(result) > 1:
        raise ValueError(f"Multiple samples found with name: {sample_name}")
    else:
        return result[0][0]  # Extract ID from tuple

def get_max_id(db_file, table, id_col):
    """
        Fetches the maximum ID from a specified table and column.

        Parameters:
            db_file (str): Path to the database file.
            table (str): Name of the table to query.
            id_col (str): Name of the ID column to find the maximum value.

        Returns:
            int: The maximum ID value plus one, or 1 if the table is empty.
        """
    conn = sqlite3.connect(db_file)
    c = conn.cursor()
    c.execute(f"SELECT MAX({id_col}) FROM {table}")
    max_id = c.fetchone()[0]
    return max_id + 1 if max_id else 1

def fetch_construct_seq(db_file, s_id):
    """
    Fetches the construct sequence for a given sample ID.

    Parameters:
        db_file (str): Path to the database file.
        s_id (int): Sample ID to fetch the construct sequence for.

    Returns:
        str: The construct sequence with T's converted to U's.
    """

    conn = sqlite3.connect(db_file)
    c = conn.cursor()
    c.execute('SELECT construct_id FROM probing_reactions WHERE s_id = ?', (s_id,))
    construct_id = c.fetchone()[0]
    c.execute('SELECT sequence FROM constructs WHERE id = ?', (construct_id,))
    construct_seq = c.fetchone()[0]
    dict_convertTU = {'T': 'U', 't': 'u'}
    construct_seq = ''.join([dict_convertTU.get(base, base) for base in construct_seq])
    conn.close()
    return construct_seq

def fetch_rxn_id(db_file, s_id):
    """
    Fetches the reaction ID for a given sample ID.

    Parameters:
        db_file (str): Path to the database file.
        s_id (int): Sample ID to fetch the reaction ID for.

    Returns:
        int: The reaction ID.
    """

    conn = sqlite3.connect(db_file)
    c = conn.cursor()
    c.execute('SELECT id, treated FROM probing_reactions WHERE s_id = ?', (s_id,))
    result = c.fetchone()
    conn.close()
    
    rxn_id = result[0]
    treated = result[1]
    return rxn_id, treated

def fetch_nt_ids(db_file, s_id):
    """
    Fetches the nucleotide IDs and sequence for a given sample ID.

    Parameters:
        db_file (str): Path to the database file.
        s_id (int): Sample ID to fetch the nucleotide IDs and sequence for.

    Returns:
        tuple: A tuple containing a list of nucleotide IDs and the nucleotide sequence with T's converted to U's.
    """
    
    conn = sqlite3.connect(db_file)
    c = conn.cursor()
    c.execute('SELECT construct_id FROM probing_reactions WHERE s_id = ?', (s_id,))
    construct_id = c.fetchone()[0]
    c.execute('SELECT id, base FROM nucleotides WHERE construct_id = ?', (construct_id,))
    selected_nts = sorted(c.fetchall())
    conn.close()

    nt_ids = [nt[0] for nt in selected_nts]
    nt_seq = ''.join([nt[1] for nt in selected_nts])
    dict_convertTU = {'T': 'U', 't': 'u'}
    nt_seq = ''.join([dict_convertTU.get(base, base) for base in nt_seq])
    return nt_ids, nt_seq

# %%
## Construct fmod_calc_run entry

def construct_fmod_calc_run(sample_name, fmod_dir, db_file, run0420 = None):

    run = glob.glob(f'/projects/b1044/Computational_Output/EKC/{fmod_dir}/*shapemapper_log*')[0]
    run_datetime, run_args, version, r1_file, untreated, denatured, sample_check = extract_info_from_log(run, sample_name, run0420)
    s_id = fetch_s_id(db_file, sample_name)

    # get potential fmod_calc id but do not add until fmod vals are good

    # Tentative fmod_calc id (pending fmod_vals check)
    fmod_calc_id = get_max_id(db_file, 'fmod_calc_runs', 'id')

    profile_txt = glob.glob(f'/projects/b1044/Computational_Output/EKC/{fmod_dir}/**/*_profile.txt', recursive=True)
    # exclude shapemapper_temp
    profile_txt = [x for x in profile_txt if 'shapemapper_temp' not in x]
    # choose profile with "reanalyzed"
    if len(profile_txt) > 1:
        profile_txt = [x for x in profile_txt if 'reanalyzed' in x]
        #print(fmod_dir, profile_txt)
    assert len(profile_txt) == 1, 'Multiple or no profile.txt files found'
    profile_txt = profile_txt[0]
    
    
    # process GAmodrate
    profile_txtga = glob.glob(f'/projects/b1044/Computational_Output/EKC/{fmod_dir}/**/*_profile.txtga', recursive=True)

    # exclude shapemapper_temp
    profile_txtga = [x for x in profile_txtga if 'shapemapper_temp' not in x]
    # choose profile with "reanalyzed"
    if len(profile_txtga) > 1:
        profile_txtga = [x for x in profile_txtga if 'reanalyzed' in x]
        #print(fmod_dir, profile_txt)
    elif len(profile_txtga) == 0:
        profile_txtga = None
    else:
        profile_txtga = profile_txtga[0]

    # handle untreated or denatured
    rxn_id, rxn_treated = fetch_rxn_id(db_file, s_id)

    use_untreated_calc = False

    if (untreated != 0) & (rxn_treated == 0):
        r1_file = untreated
        use_untreated_calc = True
    elif (denatured != 0) & (rxn_treated == 1):
        r1_file = denatured

    return run_datetime, run_args, version, use_untreated_calc, r1_file, sample_check, s_id, fmod_calc_id, profile_txt, profile_txtga

def construct_fmod_vals(profile_txt, db_file, s_id, fmod_calc_id, use_untreated_calc):
    # read the csv file
    df = pd.read_csv(profile_txt, sep='\t')
    seq_from_profile = ''.join(df['Sequence'].values)

    construct_seq = fetch_construct_seq(db_file, s_id)
    assert construct_seq.upper() == seq_from_profile.upper(), 'Construct sequence does not match profile.txt sequence'

    nt_ids, nt_seq = fetch_nt_ids(db_file, s_id)
    assert nt_seq.upper() == seq_from_profile.upper(), 'Nt sequence does not match profile.txt sequence'

    rxn_id, rxn_treated = fetch_rxn_id(db_file, s_id)

    if use_untreated_calc:
        #print('using untreated')
        fmod_vals = df['Untreated_rate'].values
        read_depths = df['Untreated_read_depth'].values
    else:
        fmod_vals = df['Modified_rate'].values
        read_depths = df['Modified_read_depth'].values

    fmod_vals_df = pd.DataFrame({'nt_id': nt_ids, 'fmod_calc_run_id': fmod_calc_id, 'fmod_val': fmod_vals, 'valtype': 'modrate', 'read_depth': read_depths, 'rxn_id': rxn_id})
    return fmod_vals_df

# %%
samples = pd.read_csv('/projects/b1044/Computational_Output/EKC/EKC.01_SHAPE_standardization/EKC.01.060.developing_DB_input/samples_import.csv')

skipped = []

i = 112
# check if sample_name column has not repeats
fmod_dir = samples[samples['RT'] == 'MRT']['fmod_runs'].values[i]
sample_name = samples[samples['RT'] == 'MRT']['sample_name'].values[i]

i = 5
# check if sample_name column has not repeats
fmod_dir = samples[samples['sequencing_run'] == 23]['fmod_runs'].values[i]
sample_name = samples[samples['sequencing_run'] == 23]['sample_name'].values[i]

i = 5
# check if sample_name column has not repeats
fmod_dir = samples[samples['RT'] == 'MRTpH9']['fmod_runs'].values[i]
sample_name = samples[samples['RT'] == 'MRTpH9']['sample_name'].values[i]


i = 5
# check if sample_name column has not repeats
fmod_dir = samples[samples['done_by'] == 'RB']['fmod_runs'].values[i]
sample_name = samples[samples['done_by'] == 'RB']['sample_name'].values[i]

# get text inside single quote '
print(fmod_dir)
if "'" in fmod_dir:
    fmod_dir = fmod_dir.split("'")[1]
print(fmod_dir)
print(sample_name)
db_file = '/projects/b1044/Computational_Output/EKC/EKC.01_SHAPE_standardization/EKC.01.060.developing_DB_input/new.db'

try:
    run_datetime, run_args, version, use_untreated_calc, r1_file, sample_check, s_id, fmod_calc_id, profile_txt, profile_txtga = construct_fmod_calc_run(sample_name, fmod_dir, db_file, True)
except:
    print('Error in log file, skipping...')
if sample_check:
    fmod_vals_df = construct_fmod_vals(profile_txt, db_file, s_id, fmod_calc_id, use_untreated_calc)
    
    if profile_txtga is not None:
        fmod_vals_df_ga = construct_fmod_vals(profile_txtga, db_file, s_id, fmod_calc_id, use_untreated_calc)
        fmod_vals_df_ga['valtype'] = 'GAmodrate'
        fmod_vals_df = pd.concat([fmod_vals_df, fmod_vals_df_ga])
else:
    print('Sample name does not match R1 file, skipping...')
    skipped.append(i)

# Append fmod_calc_run fmod_vals to db
# conn = sqlite3.connect(db_file)
# c = conn.cursor()
# c.execute('INSERT INTO fmod_calc_runs (id, s_id, run_datetime, version, r1_file) VALUES (?, ?, ?, ?, ?, ?, ?, ?)', (fmod_calc_id, s_id, run_datetime, version, r1_file))
# fmod_vals_df.to_sql('fmod_vals', conn, if_exists='append', index=False)
# conn.commit()
# conn.close()

fmod_vals_df
# Out:
# fmod_calc_runs_2/000000000260
# fmod_calc_runs_2/000000000260
# DMS-40-WTII_S4_L001_R1_001.fastq.gz
# DMS-40-WTII_S4_L001_R1_001 DMS-40-WTII_S4_L001_R1_001
# Sample name does not match R1 file, skipping...
#      nt_id  fmod_calc_run_id  fmod_val    valtype  read_depth  rxn_id
# 0      531               786       NaN    modrate       58138    1101
# 1      532               786       NaN    modrate       58192    1101
# 2      533               786       NaN    modrate       58219    1101
# 3      534               786       NaN    modrate       58228    1101
# 4      535               786       NaN    modrate       58232    1101
# ..     ...               ...       ...        ...         ...     ...
# 207    738               786       NaN  GAmodrate       58639    1101
# 208    739               786       NaN  GAmodrate       58635    1101
# 209    740               786       NaN  GAmodrate       58625    1101
# 210    741               786       NaN  GAmodrate       58607    1101
# 211    742               786       NaN  GAmodrate       58576    1101
#
# [424 rows x 6 columns]

# %%
mrt_only = samples[(samples['RT'] == 'MRT') | (samples['RT'] == 'MRTpH9')]
# drop nan values 
mrt_only = mrt_only.dropna(subset=['fmod_runs'])

for i, row in mrt_only.iterrows():
    fmod_dir = row['fmod_runs']
    sample_name = row['sample_name']

    # get text inside single quote '
    if "'" in fmod_dir:
        fmod_dir = fmod_dir.split("'")[1]
    #print(fmod_dir)
    #print(sample_name)
    if row['sequencing_run'] == 23:
        run0420 = True
    else:
        run0420 = None
    try:
        run_datetime, run_args, version, use_untreated_calc, r1_file, sample_check, s_id, fmod_calc_id, profile_txt, profile_txtga = construct_fmod_calc_run(sample_name, fmod_dir, db_file, True)
    except:
        print('---------------------------------------------')
        print(sample_name)
        traceback.print_exc()
        print('---------------------------------------------')
        continue

    if sample_check:
        fmod_vals_df = construct_fmod_vals(profile_txt, db_file, s_id, fmod_calc_id, use_untreated_calc)
        if profile_txtga is not None:
            fmod_vals_df_ga = construct_fmod_vals(profile_txtga, db_file, s_id, fmod_calc_id, use_untreated_calc)
            fmod_vals_df_ga['valtype'] = 'GAmodrate'
            fmod_vals_df = pd.concat([fmod_vals_df, fmod_vals_df_ga])
        
        # Append fmod_calc_run fmod_vals to db
        #conn = sqlite3.connect(db_file)
        #c = conn.cursor()
        #c.execute('INSERT INTO fmod_calc_runs (id, s_id, software_name, software_version, run_args, output_dir) VALUES (?, ?, ?, ?, ?, ?)', (fmod_calc_id, s_id, 'shapemapper', version, run_args, r1_file))
        #fmod_vals_df.to_sql('fmod_vals', conn, if_exists='append', index=False)
        #conn.commit()
        #conn.close()
        
        # Processed done, drop row
        mrt_only = mrt_only.drop(index=i)
    else:
        print(fmod_dir, r1_file, sample_name)
        print('Sample name does not match R1 file, skipping...')
        continue
    
mrt_only
# Out:
# RRRY-017-EKC-fourUnew-WT-II-37C-dms-MaP-0-30_S17_L001_R1_001 RRRY-017-EKC-fourUnew-WT-II-37C-dms-MaP-0-30_S17_L001_R1_001
# 017-EKC-fourUnew-WT-II-37C-dms-MaP-0-30_S17_L001_R1_001 017-EKC-fourUnew-WT-II-37C-dms-MaP-0-30_S17_L001_R1_001
# RRRY-018-EKC-fourUnew-WT-II-37C-dms-MaP-1_S18_L001_R1_001 RRRY-018-EKC-fourUnew-WT-II-37C-dms-MaP-1_S18_L001_R1_001
# 018-EKC-fourUnew-WT-II-37C-dms-MaP-1_S18_L001_R1_001 018-EKC-fourUnew-WT-II-37C-dms-MaP-1_S18_L001_R1_001
# RRRY-019-EKC-fourUnew-WT-II-37C-dms-MaP-20_S19_L001_R1_001 RRRY-019-EKC-fourUnew-WT-II-37C-dms-MaP-20_S19_L001_R1_001
# 019-EKC-fourUnew-WT-II-37C-dms-MaP-20_S19_L001_R1_001 019-EKC-fourUnew-WT-II-37C-dms-MaP-20_S19_L001_R1_001
# RRRY-020-EKC-fourUnew-WT-II-37C-dms-MaP-40_S20_L001_R1_001 RRRY-020-EKC-fourUnew-WT-II-37C-dms-MaP-40_S20_L001_R1_001
# 020-EKC-fourUnew-WT-II-37C-dms-MaP-40_S20_L001_R1_001 020-EKC-fourUnew-WT-II-37C-dms-MaP-40_S20_L001_R1_001
# RRRY-021-EKC-fourUnew-WT-II-37C-dms-MaP-60_S21_L001_R1_001 RRRY-021-EKC-fourUnew-WT-II-37C-dms-MaP-60_S21_L001_R1_001
# 021-EKC-fourUnew-WT-II-37C-dms-MaP-60_S21_L001_R1_001 021-EKC-fourUnew-WT-II-37C-dms-MaP-60_S21_L001_R1_001
# RRRY-022-EKC-fourUnew-WT-II-37C-dms-MaP-90_S22_L001_R1_001 RRRY-022-EKC-fourUnew-WT-II-37C-dms-MaP-90_S22_L001_R1_001
# 022-EKC-fourUnew-WT-II-37C-dms-MaP-90_S22_L001_R1_001 022-EKC-fourUnew-WT-II-37C-dms-MaP-90_S22_L001_R1_001
# RRRY-023-EKC-fourUnew-WT-II-37C-dms-MaP-120_S23_L001_R1_001 RRRY-023-EKC-fourUnew-WT-II-37C-dms-MaP-120_S23_L001_R1_001
# 023-EKC-fourUnew-WT-II-37C-dms-MaP-120_S23_L001_R1_001 023-EKC-fourUnew-WT-II-37C-dms-MaP-120_S23_L001_R1_001
# RRRY-017-EKC-fourUnew-A8C-II-37C-dms-MaP-0-30_S17_L001_R1_001 RRRY-017-EKC-fourUnew-A8C-II-37C-dms-MaP-0-30_S17_L001_R1_001
# 017-EKC-fourUnew-A8C-II-37C-dms-MaP-0-30_S17_L001_R1_001 017-EKC-fourUnew-A8C-II-37C-dms-MaP-0-30_S17_L001_R1_001
# RRRY-018-EKC-fourUnew-A8C-II-37C-dms-MaP-1_S18_L001_R1_001 RRRY-018-EKC-fourUnew-A8C-II-37C-dms-MaP-1_S18_L001_R1_001
# 018-EKC-fourUnew-A8C-II-37C-dms-MaP-1_S18_L001_R1_001 018-EKC-fourUnew-A8C-II-37C-dms-MaP-1_S18_L001_R1_001
# RRRY-019-EKC-fourUnew-A8C-II-37C-dms-MaP-20_S19_L001_R1_001 RRRY-019-EKC-fourUnew-A8C-II-37C-dms-MaP-20_S19_L001_R1_001
# 019-EKC-fourUnew-A8C-II-37C-dms-MaP-20_S19_L001_R1_001 019-EKC-fourUnew-A8C-II-37C-dms-MaP-20_S19_L001_R1_001
# RRRY-020-EKC-fourUnew-A8C-II-37C-dms-MaP-40_S20_L001_R1_001 RRRY-020-EKC-fourUnew-A8C-II-37C-dms-MaP-40_S20_L001_R1_001
# 020-EKC-fourUnew-A8C-II-37C-dms-MaP-40_S20_L001_R1_001 020-EKC-fourUnew-A8C-II-37C-dms-MaP-40_S20_L001_R1_001
# RRRY-021-EKC-fourUnew-A8C-II-37C-dms-MaP-60_S21_L001_R1_001 RRRY-021-EKC-fourUnew-A8C-II-37C-dms-MaP-60_S21_L001_R1_001
# 021-EKC-fourUnew-A8C-II-37C-dms-MaP-60_S21_L001_R1_001 021-EKC-fourUnew-A8C-II-37C-dms-MaP-60_S21_L001_R1_001
# RRRY-022-EKC-fourUnew-A8C-II-37C-dms-MaP-90_S22_L001_R1_001 RRRY-022-EKC-fourUnew-A8C-II-37C-dms-MaP-90_S22_L001_R1_001
# 022-EKC-fourUnew-A8C-II-37C-dms-MaP-90_S22_L001_R1_001 022-EKC-fourUnew-A8C-II-37C-dms-MaP-90_S22_L001_R1_001
# RRRY-023-EKC-fourUnew-A8C-II-37C-dms-MaP-120_S23_L001_R1_001 RRRY-023-EKC-fourUnew-A8C-II-37C-dms-MaP-120_S23_L001_R1_001
# 023-EKC-fourUnew-A8C-II-37C-dms-MaP-120_S23_L001_R1_001 023-EKC-fourUnew-A8C-II-37C-dms-MaP-120_S23_L001_R1_001
# RRRY-024-EKC-fourUnew-A8C-II-37C-dms-MaP-150_S24_L001_R1_001 RRRY-024-EKC-fourUnew-A8C-II-37C-dms-MaP-150_S24_L001_R1_001
# 024-EKC-fourUnew-A8C-II-37C-dms-MaP-150_S24_L001_R1_001 024-EKC-fourUnew-A8C-II-37C-dms-MaP-150_S24_L001_R1_001
# DMS-05-WTII_S1_L001_R1_001 DMS-05-WTII_S1_L001_R1_001
# DMS-1-WTII_S2_L001_R1_001 DMS-1-WTII_S2_L001_R1_001
# fmod_calc_runs_2/000000000258 ./DMS-1-WTII_S2_L001_R1_001.fastq.gz DMS-1-WTII_S2_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-120-WTII_S7_L001_R1_001 DMS-120-WTII_S7_L001_R1_001
# fmod_calc_runs_2/000000000263 ./DMS-120-WTII_S7_L001_R1_001.fastq.gz DMS-120-WTII_S7_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-150-WTII_S8_L001_R1_001 DMS-150-WTII_S8_L001_R1_001
# fmod_calc_runs_2/000000000264 ./DMS-150-WTII_S8_L001_R1_001.fastq.gz DMS-150-WTII_S8_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-20-WTII_S3_L001_R1_001 DMS-20-WTII_S3_L001_R1_001
# fmod_calc_runs_2/000000000259 ./DMS-20-WTII_S3_L001_R1_001.fastq.gz DMS-20-WTII_S3_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-40-WTII_S4_L001_R1_001 DMS-40-WTII_S4_L001_R1_001
# fmod_calc_runs_2/000000000260 ./DMS-40-WTII_S4_L001_R1_001.fastq.gz DMS-40-WTII_S4_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-60-WTII_S5_L001_R1_001 DMS-60-WTII_S5_L001_R1_001
# fmod_calc_runs_2/000000000261 ./DMS-60-WTII_S5_L001_R1_001.fastq.gz DMS-60-WTII_S5_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-90-WTII_S6_L001_R1_001 DMS-90-WTII_S6_L001_R1_001
# fmod_calc_runs_2/000000000262 ./DMS-90-WTII_S6_L001_R1_001.fastq.gz DMS-90-WTII_S6_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 05-WTII 05-WTII
# 1-WTII 1-WTII
# fmod_calc_runs_2/000000000258 ./etOH-1-WTII_S10_L001_R1_001.fastq.gz etOH-1-WTII_S10_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 120-WTII 120-WTII
# fmod_calc_runs_2/000000000263 ./etOH-120-WTII_S15_L001_R1_001.fastq.gz etOH-120-WTII_S15_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 150-WTII 150-WTII
# fmod_calc_runs_2/000000000264 ./etOH-150-WTII_S16_L001_R1_001.fastq.gz etOH-150-WTII_S16_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 20-WTII 20-WTII
# fmod_calc_runs_2/000000000259 ./etOH-20-WTII_S11_L001_R1_001.fastq.gz etOH-20-WTII_S11_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 40-WTII 40-WTII
# fmod_calc_runs_2/000000000260 ./etOH-40-WTII_S12_L001_R1_001.fastq.gz etOH-40-WTII_S12_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 60-WTII 60-WTII
# fmod_calc_runs_2/000000000261 ./etOH-60-WTII_S13_L001_R1_001.fastq.gz etOH-60-WTII_S13_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 90-WTII 90-WTII
# fmod_calc_runs_2/000000000262 ./etOH-90-WTII_S14_L001_R1_001.fastq.gz etOH-90-WTII_S14_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-05-A8CII_S1_L001_R1_001 DMS-05-A8CII_S1_L001_R1_001
# DMS-1-A8CII_S2_L001_R1_001 DMS-1-A8CII_S2_L001_R1_001
# fmod_calc_runs_2/000000000266 ./DMS-1-A8CII_S2_L001_R1_001.fastq.gz DMS-1-A8CII_S2_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-120-A8CII_S7_L001_R1_001 DMS-120-A8CII_S7_L001_R1_001
# fmod_calc_runs_2/000000000271 ./DMS-120-A8CII_S7_L001_R1_001.fastq.gz DMS-120-A8CII_S7_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-150-A8CII_S8_L001_R1_001 DMS-150-A8CII_S8_L001_R1_001
# fmod_calc_runs_2/000000000272 ./DMS-150-A8CII_S8_L001_R1_001.fastq.gz DMS-150-A8CII_S8_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-20-A8CII_S3_L001_R1_001 DMS-20-A8CII_S3_L001_R1_001
# fmod_calc_runs_2/000000000267 ./DMS-20-A8CII_S3_L001_R1_001.fastq.gz DMS-20-A8CII_S3_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-40-A8CII_S4_L001_R1_001 DMS-40-A8CII_S4_L001_R1_001
# fmod_calc_runs_2/000000000268 ./DMS-40-A8CII_S4_L001_R1_001.fastq.gz DMS-40-A8CII_S4_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-60-A8CII_S5_L001_R1_001 DMS-60-A8CII_S5_L001_R1_001
# fmod_calc_runs_2/000000000269 ./DMS-60-A8CII_S5_L001_R1_001.fastq.gz DMS-60-A8CII_S5_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# DMS-90-A8CII_S6_L001_R1_001 DMS-90-A8CII_S6_L001_R1_001
# fmod_calc_runs_2/000000000270 ./DMS-90-A8CII_S6_L001_R1_001.fastq.gz DMS-90-A8CII_S6_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 05-A8CII 05-A8CII
# 1-A8CII 1-A8CII
# fmod_calc_runs_2/000000000266 ./etOH-1-A8CII_S10_L001_R1_001.fastq.gz etOH-1-A8CII_S10_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 120-A8CII 120-A8CII
# fmod_calc_runs_2/000000000271 ./etOH-120-A8CII_S15_L001_R1_001.fastq.gz etOH-120-A8CII_S15_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 150-A8CII 150-A8CII
# fmod_calc_runs_2/000000000272 ./etOH-150-A8CII_S16_L001_R1_001.fastq.gz etOH-150-A8CII_S16_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 20-A8CII 20-A8CII
# fmod_calc_runs_2/000000000267 ./etOH-20-A8CII_S11_L001_R1_001.fastq.gz etOH-20-A8CII_S11_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 40-A8CII 40-A8CII
# fmod_calc_runs_2/000000000268 ./etOH-40-A8CII_S12_L001_R1_001.fastq.gz etOH-40-A8CII_S12_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 60-A8CII 60-A8CII
# fmod_calc_runs_2/000000000269 ./etOH-60-A8CII_S13_L001_R1_001.fastq.gz etOH-60-A8CII_S13_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 90-A8CII 90-A8CII
# fmod_calc_runs_2/000000000270 ./etOH-90-A8CII_S14_L001_R1_001.fastq.gz etOH-90-A8CII_S14_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# RRRY-001-EKC-fourUnew-WT-25C-dms-MaP-6_S1_L001_R1_001 RRRY-001-EKC-fourUnew-WT-25C-dms-MaP-6_S1_L001_R1_001
# 001-EKC-fourUnew-WT-25C-dms-MaP-6_S1_L001_R1_001 001-EKC-fourUnew-WT-25C-dms-MaP-6_S1_L001_R1_001
# RRRY-002-EKC-fourUnew-WT-25C-dms-MaP-25_S2_L001_R1_001 RRRY-002-EKC-fourUnew-WT-25C-dms-MaP-25_S2_L001_R1_001
# 002-EKC-fourUnew-WT-25C-dms-MaP-25_S2_L001_R1_001 002-EKC-fourUnew-WT-25C-dms-MaP-25_S2_L001_R1_001
# RRRY-003-EKC-fourUnew-WT-25C-dms-MaP-60_S3_L001_R1_001 RRRY-003-EKC-fourUnew-WT-25C-dms-MaP-60_S3_L001_R1_001
# 003-EKC-fourUnew-WT-25C-dms-MaP-60_S3_L001_R1_001 003-EKC-fourUnew-WT-25C-dms-MaP-60_S3_L001_R1_001
# RRRY-004-EKC-fourUnew-WT-25C-dms-MaP-120_S4_L001_R1_001 RRRY-004-EKC-fourUnew-WT-25C-dms-MaP-120_S4_L001_R1_001
# 004-EKC-fourUnew-WT-25C-dms-MaP-120_S4_L001_R1_001 004-EKC-fourUnew-WT-25C-dms-MaP-120_S4_L001_R1_001
# RRRY-005-EKC-fourUnew-WT-25C-dms-MaP-180_S5_L001_R1_001 RRRY-005-EKC-fourUnew-WT-25C-dms-MaP-180_S5_L001_R1_001
# 005-EKC-fourUnew-WT-25C-dms-MaP-180_S5_L001_R1_001 005-EKC-fourUnew-WT-25C-dms-MaP-180_S5_L001_R1_001
# RRRY-006-EKC-fourUnew-WT-25C-dms-MaP-240_S6_L001_R1_001 RRRY-006-EKC-fourUnew-WT-25C-dms-MaP-240_S6_L001_R1_001
# 006-EKC-fourUnew-WT-25C-dms-MaP-240_S6_L001_R1_001 006-EKC-fourUnew-WT-25C-dms-MaP-240_S6_L001_R1_001
# RRRY-007-EKC-fourUnew-A8C-25C-dms-MaP-6_S7_L001_R1_001 RRRY-007-EKC-fourUnew-A8C-25C-dms-MaP-6_S7_L001_R1_001
# 007-EKC-fourUnew-A8C-25C-dms-MaP-6_S7_L001_R1_001 007-EKC-fourUnew-A8C-25C-dms-MaP-6_S7_L001_R1_001
# RRRY-008-EKC-fourUnew-A8C-25C-dms-MaP-25_S8_L001_R1_001 RRRY-008-EKC-fourUnew-A8C-25C-dms-MaP-25_S8_L001_R1_001
# 008-EKC-fourUnew-A8C-25C-dms-MaP-25_S8_L001_R1_001 008-EKC-fourUnew-A8C-25C-dms-MaP-25_S8_L001_R1_001
# RRRY-009-EKC-fourUnew-A8C-25C-dms-MaP-60_S9_L001_R1_001 RRRY-009-EKC-fourUnew-A8C-25C-dms-MaP-60_S9_L001_R1_001
# 009-EKC-fourUnew-A8C-25C-dms-MaP-60_S9_L001_R1_001 009-EKC-fourUnew-A8C-25C-dms-MaP-60_S9_L001_R1_001
# RRRY-010-EKC-fourUnew-A8C-25C-dms-MaP-120_S10_L001_R1_001 RRRY-010-EKC-fourUnew-A8C-25C-dms-MaP-120_S10_L001_R1_001
# 010-EKC-fourUnew-A8C-25C-dms-MaP-120_S10_L001_R1_001 010-EKC-fourUnew-A8C-25C-dms-MaP-120_S10_L001_R1_001
# RRRY-011-EKC-fourUnew-A8C-25C-dms-MaP-180_S11_L001_R1_001 RRRY-011-EKC-fourUnew-A8C-25C-dms-MaP-180_S11_L001_R1_001
# 011-EKC-fourUnew-A8C-25C-dms-MaP-180_S11_L001_R1_001 011-EKC-fourUnew-A8C-25C-dms-MaP-180_S11_L001_R1_001
# RRRY-012-EKC-fourUnew-A8C-25C-dms-MaP-240_S12_L001_R1_001 RRRY-012-EKC-fourUnew-A8C-25C-dms-MaP-240_S12_L001_R1_001
# 012-EKC-fourUnew-A8C-25C-dms-MaP-240_S12_L001_R1_001 012-EKC-fourUnew-A8C-25C-dms-MaP-240_S12_L001_R1_001
# RRRY-013-EKC-fourUnew-WT-45C-dms-MaP-3_S13_L001_R1_001 RRRY-013-EKC-fourUnew-WT-45C-dms-MaP-3_S13_L001_R1_001
# 013-EKC-fourUnew-WT-45C-dms-MaP-3_S13_L001_R1_001 013-EKC-fourUnew-WT-45C-dms-MaP-3_S13_L001_R1_001
# RRRY-014-EKC-fourUnew-WT-45C-dms-MaP-6_S14_L001_R1_001 RRRY-014-EKC-fourUnew-WT-45C-dms-MaP-6_S14_L001_R1_001
# 014-EKC-fourUnew-WT-45C-dms-MaP-6_S14_L001_R1_001 014-EKC-fourUnew-WT-45C-dms-MaP-6_S14_L001_R1_001
# RRRY-015-EKC-fourUnew-WT-45C-dms-MaP-10_S15_L001_R1_001 RRRY-015-EKC-fourUnew-WT-45C-dms-MaP-10_S15_L001_R1_001
# 015-EKC-fourUnew-WT-45C-dms-MaP-10_S15_L001_R1_001 015-EKC-fourUnew-WT-45C-dms-MaP-10_S15_L001_R1_001
# RRRY-016-EKC-fourUnew-WT-45C-dms-MaP-25_S16_L001_R1_001 RRRY-016-EKC-fourUnew-WT-45C-dms-MaP-25_S16_L001_R1_001
# 016-EKC-fourUnew-WT-45C-dms-MaP-25_S16_L001_R1_001 016-EKC-fourUnew-WT-45C-dms-MaP-25_S16_L001_R1_001
# RRRY-017-EKC-fourUnew-WT-45C-dms-MaP-30_S17_L001_R1_001 RRRY-017-EKC-fourUnew-WT-45C-dms-MaP-30_S17_L001_R1_001
# 017-EKC-fourUnew-WT-45C-dms-MaP-30_S17_L001_R1_001 017-EKC-fourUnew-WT-45C-dms-MaP-30_S17_L001_R1_001
# RRRY-018-EKC-fourUnew-WT-45C-dms-MaP-45_S18_L001_R1_001 RRRY-018-EKC-fourUnew-WT-45C-dms-MaP-45_S18_L001_R1_001
# 018-EKC-fourUnew-WT-45C-dms-MaP-45_S18_L001_R1_001 018-EKC-fourUnew-WT-45C-dms-MaP-45_S18_L001_R1_001
# RRRY-019-EKC-fourUnew-A8C-45C-dms-MaP-1_S19_L001_R1_001 RRRY-019-EKC-fourUnew-A8C-45C-dms-MaP-1_S19_L001_R1_001
# 019-EKC-fourUnew-A8C-45C-dms-MaP-1_S19_L001_R1_001 019-EKC-fourUnew-A8C-45C-dms-MaP-1_S19_L001_R1_001
# RRRY-020-EKC-fourUnew-A8C-45C-dms-MaP-3_S20_L001_R1_001 RRRY-020-EKC-fourUnew-A8C-45C-dms-MaP-3_S20_L001_R1_001
# 020-EKC-fourUnew-A8C-45C-dms-MaP-3_S20_L001_R1_001 020-EKC-fourUnew-A8C-45C-dms-MaP-3_S20_L001_R1_001
# RRRY-021-EKC-fourUnew-A8C-45C-dms-MaP-6_S21_L001_R1_001 RRRY-021-EKC-fourUnew-A8C-45C-dms-MaP-6_S21_L001_R1_001
# 021-EKC-fourUnew-A8C-45C-dms-MaP-6_S21_L001_R1_001 021-EKC-fourUnew-A8C-45C-dms-MaP-6_S21_L001_R1_001
# RRRY-022-EKC-fourUnew-A8C-45C-dms-MaP-10_S22_L001_R1_001 RRRY-022-EKC-fourUnew-A8C-45C-dms-MaP-10_S22_L001_R1_001
# 022-EKC-fourUnew-A8C-45C-dms-MaP-10_S22_L001_R1_001 022-EKC-fourUnew-A8C-45C-dms-MaP-10_S22_L001_R1_001
# RRRY-023-EKC-fourUnew-A8C-45C-dms-MaP-16_S23_L001_R1_001 RRRY-023-EKC-fourUnew-A8C-45C-dms-MaP-16_S23_L001_R1_001
# 023-EKC-fourUnew-A8C-45C-dms-MaP-16_S23_L001_R1_001 023-EKC-fourUnew-A8C-45C-dms-MaP-16_S23_L001_R1_001
# RRRY-024-EKC-fourUnew-A8C-45C-dms-MaP-25_S24_L001_R1_001 RRRY-024-EKC-fourUnew-A8C-45C-dms-MaP-25_S24_L001_R1_001
# 024-EKC-fourUnew-A8C-45C-dms-MaP-25_S24_L001_R1_001 024-EKC-fourUnew-A8C-45C-dms-MaP-25_S24_L001_R1_001
# RRRYRRRY-001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001 RRRY001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001
# RRRYRRRY-001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001 RRRY001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001
# RRRY-001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001 001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001
# RRRY-001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001 001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001
# RRRYRRRY-003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001 RRRY002-EKC-fourUnew-WT-70C-dms-MaP-2S2L001R1001
# RRRYRRRY-003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001 RRRY002-EKC-fourUnew-WT-70C-dms-MaP-2S2L001R1001
# RRRY-003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001 002-EKC-fourUnew-WT-70C-dms-MaP-2S2L001R1001
# RRRY-003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001 002-EKC-fourUnew-WT-70C-dms-MaP-2S2L001R1001
# RRRYRRRY-005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001 RRRY003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001
# RRRYRRRY-005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001 RRRY003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001
# RRRY-005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001 003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001
# RRRY-005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001 003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001
# RRRYYYYR-001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001 RRRY004-EKC-fourUnew-WT-70C-dms-MaP-4S4L001R1001
# RRRYYYYR-001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001 RRRY004-EKC-fourUnew-WT-70C-dms-MaP-4S4L001R1001
# YYYR-001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001 004-EKC-fourUnew-WT-70C-dms-MaP-4S4L001R1001
# YYYR-001-EKC-fourUnew-WT-70C-dms-MaP-1S1L001R1001 004-EKC-fourUnew-WT-70C-dms-MaP-4S4L001R1001
# RRRYYYYR-003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001 RRRY005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001
# RRRYYYYR-003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001 RRRY005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001
# YYYR-003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001 005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001
# YYYR-003-EKC-fourUnew-WT-70C-dms-MaP-3S3L001R1001 005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001
# RRRYYYYR-005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001 RRRY006-EKC-fourUnew-WT-70C-dms-MaP-6S6L001R1001
# RRRYYYYR-005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001 RRRY006-EKC-fourUnew-WT-70C-dms-MaP-6S6L001R1001
# YYYR-005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001 006-EKC-fourUnew-WT-70C-dms-MaP-6S6L001R1001
# YYYR-005-EKC-fourUnew-WT-70C-dms-MaP-5S5L001R1001 006-EKC-fourUnew-WT-70C-dms-MaP-6S6L001R1001
# RRRYRRRY-007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001 RRRY007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001
# RRRYRRRY-007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001 RRRY007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001
# RRRY-007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001 007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001
# RRRY-007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001 007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001
# RRRYRRRY-009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001 RRRY008-EKC-fourUnew-WT-75C-dms-MaP-2S8L001R1001
# RRRYRRRY-009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001 RRRY008-EKC-fourUnew-WT-75C-dms-MaP-2S8L001R1001
# RRRY-009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001 008-EKC-fourUnew-WT-75C-dms-MaP-2S8L001R1001
# RRRY-009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001 008-EKC-fourUnew-WT-75C-dms-MaP-2S8L001R1001
# RRRYRRRY-011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001 RRRY009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001
# RRRYRRRY-011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001 RRRY009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001
# RRRY-011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001 009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001
# RRRY-011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001 009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001
# RRRYYYYR-007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001 RRRY010-EKC-fourUnew-WT-75C-dms-MaP-4S10L001R1001
# RRRYYYYR-007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001 RRRY010-EKC-fourUnew-WT-75C-dms-MaP-4S10L001R1001
# YYYR-007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001 010-EKC-fourUnew-WT-75C-dms-MaP-4S10L001R1001
# YYYR-007-EKC-fourUnew-WT-75C-dms-MaP-1S7L001R1001 010-EKC-fourUnew-WT-75C-dms-MaP-4S10L001R1001
# RRRYYYYR-009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001 RRRY011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001
# RRRYYYYR-009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001 RRRY011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001
# YYYR-009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001 011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001
# YYYR-009-EKC-fourUnew-WT-75C-dms-MaP-3S9L001R1001 011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001
# RRRYYYYR-011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001 RRRY012-EKC-fourUnew-WT-75C-dms-MaP-6S12L001R1001
# RRRYYYYR-011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001 RRRY012-EKC-fourUnew-WT-75C-dms-MaP-6S12L001R1001
# YYYR-011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001 012-EKC-fourUnew-WT-75C-dms-MaP-6S12L001R1001
# YYYR-011-EKC-fourUnew-WT-75C-dms-MaP-5S11L001R1001 012-EKC-fourUnew-WT-75C-dms-MaP-6S12L001R1001
# RRRYRRRY-013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001 RRRY013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001
# RRRYRRRY-013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001 RRRY013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001
# RRRY-013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001 013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001
# RRRY-013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001 013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001
# RRRYRRRY-015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001 RRRY014-EKC-fourUnew-WT-80C-dms-MaP-2S14L001R1001
# RRRYRRRY-015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001 RRRY014-EKC-fourUnew-WT-80C-dms-MaP-2S14L001R1001
# RRRY-015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001 014-EKC-fourUnew-WT-80C-dms-MaP-2S14L001R1001
# RRRY-015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001 014-EKC-fourUnew-WT-80C-dms-MaP-2S14L001R1001
# RRRYRRRY-017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001 RRRY015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001
# RRRYRRRY-017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001 RRRY015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001
# RRRY-017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001 015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001
# RRRY-017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001 015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001
# RRRYYYYR-013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001 RRRY016-EKC-fourUnew-WT-80C-dms-MaP-4S16L001R1001
# RRRYYYYR-013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001 RRRY016-EKC-fourUnew-WT-80C-dms-MaP-4S16L001R1001
# YYYR-013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001 016-EKC-fourUnew-WT-80C-dms-MaP-4S16L001R1001
# YYYR-013-EKC-fourUnew-WT-80C-dms-MaP-1S13L001R1001 016-EKC-fourUnew-WT-80C-dms-MaP-4S16L001R1001
# RRRYYYYR-015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001 RRRY017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001
# RRRYYYYR-015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001 RRRY017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001
# YYYR-015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001 017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001
# YYYR-015-EKC-fourUnew-WT-80C-dms-MaP-3S15L001R1001 017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001
# RRRYYYYR-017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001 RRRY018-EKC-fourUnew-WT-80C-dms-MaP-6S18L001R1001
# RRRYYYYR-017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001 RRRY018-EKC-fourUnew-WT-80C-dms-MaP-6S18L001R1001
# YYYR-017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001 018-EKC-fourUnew-WT-80C-dms-MaP-6S18L001R1001
# YYYR-017-EKC-fourUnew-WT-80C-dms-MaP-5S17L001R1001 018-EKC-fourUnew-WT-80C-dms-MaP-6S18L001R1001
# RRRYRRRY-019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001 RRRY019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001
# RRRYRRRY-019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001 RRRY019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001
# RRRY-019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001 019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001
# RRRY-019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001 019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001
# RRRYRRRY-021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001 RRRY020-EKC-fourUnew-WT-85C-dms-MaP-2S20L001R1001
# RRRYRRRY-021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001 RRRY020-EKC-fourUnew-WT-85C-dms-MaP-2S20L001R1001
# RRRY-021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001 020-EKC-fourUnew-WT-85C-dms-MaP-2S20L001R1001
# RRRY-021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001 020-EKC-fourUnew-WT-85C-dms-MaP-2S20L001R1001
# RRRYRRRY-023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001 RRRY021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001
# RRRYRRRY-023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001 RRRY021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001
# RRRY-023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001 021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001
# RRRY-023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001 021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001
# RRRYYYYR-019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001 RRRY022-EKC-fourUnew-WT-85C-dms-MaP-4S22L001R1001
# RRRYYYYR-019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001 RRRY022-EKC-fourUnew-WT-85C-dms-MaP-4S22L001R1001
# YYYR-019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001 022-EKC-fourUnew-WT-85C-dms-MaP-4S22L001R1001
# YYYR-019-EKC-fourUnew-WT-85C-dms-MaP-1S19L001R1001 022-EKC-fourUnew-WT-85C-dms-MaP-4S22L001R1001
# RRRYYYYR-021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001 RRRY023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001
# RRRYYYYR-021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001 RRRY023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001
# YYYR-021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001 023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001
# YYYR-021-EKC-fourUnew-WT-85C-dms-MaP-3S21L001R1001 023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001
# RRRYYYYR-023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001 RRRY024-EKC-fourUnew-WT-85C-dms-MaP-6S24L001R1001
# RRRYYYYR-023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001 RRRY024-EKC-fourUnew-WT-85C-dms-MaP-6S24L001R1001
# YYYR-023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001 024-EKC-fourUnew-WT-85C-dms-MaP-6S24L001R1001
# YYYR-023-EKC-fourUnew-WT-85C-dms-MaP-5S23L001R1001 024-EKC-fourUnew-WT-85C-dms-MaP-6S24L001R1001
# 001-EKC-WT-60c-a-1-p_S1_L001_R1_001 001-EKC-WT-60c-a-1-p_S1_L001_R1_001
# 002-EKC-WT-60c-a-2-p_S2_L001_R1_001 002-EKC-WT-60c-a-2-p_S2_L001_R1_001
# 003-EKC-WT-60c-a-3-p_S3_L001_R1_001 003-EKC-WT-60c-a-3-p_S3_L001_R1_001
# 004-EKC-WT-60c-a-4-p_S4_L001_R1_001 004-EKC-WT-60c-a-4-p_S4_L001_R1_001
# 005-EKC-WT-60c-a-5-p_S5_L001_R1_001 005-EKC-WT-60c-a-5-p_S5_L001_R1_001
# 006-EKC-WT-60c-a-6-p_S6_L001_R1_001 006-EKC-WT-60c-a-6-p_S6_L001_R1_001
# 007-EKC-WT-60c-b-1-p_S7_L001_R1_001 007-EKC-WT-60c-b-1-p_S7_L001_R1_001
# 008-EKC-WT-60c-b-2-p_S8_L001_R1_001 008-EKC-WT-60c-b-2-p_S8_L001_R1_001
# 009-EKC-WT-60c-b-3-p_S9_L001_R1_001 009-EKC-WT-60c-b-3-p_S9_L001_R1_001
# 010-EKC-WT-60c-b-4-p_S10_L001_R1_001 010-EKC-WT-60c-b-4-p_S10_L001_R1_001
# 011-EKC-WT-60c-b-5-p_S11_L001_R1_001 011-EKC-WT-60c-b-5-p_S11_L001_R1_001
# 012-EKC-WT-60c-b-6-p_S12_L001_R1_001 012-EKC-WT-60c-b-6-p_S12_L001_R1_001
# 013-EKC-WT-70c-b-1-p_S13_L001_R1_001 013-EKC-WT-70c-b-1-p_S13_L001_R1_001
# 015-EKC-WT-70c-b-3-p_S15_L001_R1_001 015-EKC-WT-70c-b-3-p_S15_L001_R1_001
# 016-EKC-WT-70c-b-4-p_S16_L001_R1_001 016-EKC-WT-70c-b-4-p_S16_L001_R1_001
# 017-EKC-WT-70c-b-5-p_S17_L001_R1_001 017-EKC-WT-70c-b-5-p_S17_L001_R1_001
# 018-EKC-WT-70c-b-6-p_S18_L001_R1_001 018-EKC-WT-70c-b-6-p_S18_L001_R1_001
# 019-EKC-WT-75c-b-1-p_S19_L001_R1_001 019-EKC-WT-75c-b-1-p_S19_L001_R1_001
# 020-EKC-WT-75c-b-2-p_S20_L001_R1_001 020-EKC-WT-75c-b-2-p_S20_L001_R1_001
# 021-EKC-WT-75c-b-3-p_S21_L001_R1_001 021-EKC-WT-75c-b-3-p_S21_L001_R1_001
# 022-EKC-WT-75c-b-4-p_S22_L001_R1_001 022-EKC-WT-75c-b-4-p_S22_L001_R1_001
# 023-EKC-WT-75c-b-5-p_S23_L001_R1_001 023-EKC-WT-75c-b-5-p_S23_L001_R1_001
# 024-EKC-WT-75c-b-6-p_S24_L001_R1_001 024-EKC-WT-75c-b-6-p_S24_L001_R1_001
# 025-EKC-WT-80c-b-1-p_S25_L001_R1_001 025-EKC-WT-80c-b-1-p_S25_L001_R1_001
# 026-EKC-WT-80c-b-2-p_S26_L001_R1_001 026-EKC-WT-80c-b-2-p_S26_L001_R1_001
# 027-EKC-WT-80c-b-3-p_S27_L001_R1_001 027-EKC-WT-80c-b-3-p_S27_L001_R1_001
# 028-EKC-WT-80c-b-4-p_S28_L001_R1_001 028-EKC-WT-80c-b-4-p_S28_L001_R1_001
# 029-EKC-WT-80c-b-5-p_S29_L001_R1_001 029-EKC-WT-80c-b-5-p_S29_L001_R1_001
# 030-EKC-WT-80c-b-6-p_S30_L001_R1_001 030-EKC-WT-80c-b-6-p_S30_L001_R1_001
# 031-EKC-WT-30c-b-6-m_S31_L001_R1_001 031-EKC-WT-30c-b-6-m_S31_L001_R1_001
# 032-EKC-WT-37c-b-6-m_S32_L001_R1_001 032-EKC-WT-37c-b-6-m_S32_L001_R1_001
# 033-EKC-WT-45c-b-6-m_S33_L001_R1_001 033-EKC-WT-45c-b-6-m_S33_L001_R1_001
# 034-EKC-WT-52c-a-6-m_S34_L001_R1_001 034-EKC-WT-52c-a-6-m_S34_L001_R1_001
# 035-EKC-WT-52c-b-6-m_S35_L001_R1_001 035-EKC-WT-52c-b-6-m_S35_L001_R1_001
# 036-EKC-WT-60c-a-6-m_S36_L001_R1_001 036-EKC-WT-60c-a-6-m_S36_L001_R1_001
# 037-EKC-WT-52c-a-6-m_S37_L001_R1_001 037-EKC-WT-52c-a-6-m_S37_L001_R1_001
# 038-EKC-WT-52c-b-6-m_S38_L001_R1_001 038-EKC-WT-52c-b-6-m_S38_L001_R1_001
# 039-EKC-WT-60c-b-6-m_S39_L001_R1_001 039-EKC-WT-60c-b-6-m_S39_L001_R1_001
# 040-EKC-WT-70c-b-6-m_S40_L001_R1_001 040-EKC-WT-70c-b-6-m_S40_L001_R1_001
# 041-EKC-WT-75c-b-6-m_S41_L001_R1_001 041-EKC-WT-75c-b-6-m_S41_L001_R1_001
# 042-EKC-WT-80c-b-6-m_S42_L001_R1_001 042-EKC-WT-80c-b-6-m_S42_L001_R1_001
# 043-EKC-A8C-70c-a-6-m_S43_L001_R1_001 043-EKC-A8C-70c-a-6-m_S43_L001_R1_001
# 044-EKC-A8C-70c-b-6-m_S44_L001_R1_001 044-EKC-A8C-70c-b-6-m_S44_L001_R1_001
# 045-EKC-A8C-75c-a-6-m_S45_L001_R1_001 045-EKC-A8C-75c-a-6-m_S45_L001_R1_001
# 046-EKC-A8C-75c-b-6-m_S46_L001_R1_001 046-EKC-A8C-75c-b-6-m_S46_L001_R1_001
# 047-EKC-A8C-80c-a-6-m_S47_L001_R1_001 047-EKC-A8C-80c-a-6-m_S47_L001_R1_001
# 048-EKC-A8C-80c-b-6-m_S48_L001_R1_001 048-EKC-A8C-80c-b-6-m_S48_L001_R1_001
# 049-EKC-WT-25c-b-1-p_S49_L001_R1_001 049-EKC-WT-25c-b-1-p_S49_L001_R1_001
# 050-EKC-WT-25c-b-2-p_S50_L001_R1_001 050-EKC-WT-25c-b-2-p_S50_L001_R1_001
# 051-EKC-WT-25c-b-3-p_S51_L001_R1_001 051-EKC-WT-25c-b-3-p_S51_L001_R1_001
# 052-EKC-WT-25c-b-4-p_S52_L001_R1_001 052-EKC-WT-25c-b-4-p_S52_L001_R1_001
# 053-EKC-WT-25c-b-5-p_S53_L001_R1_001 053-EKC-WT-25c-b-5-p_S53_L001_R1_001
# 054-EKC-WT-25c-b-6-p_S54_L001_R1_001 054-EKC-WT-25c-b-6-p_S54_L001_R1_001
# 055-EKC-WT-30c-a-1-p_S55_L001_R1_001 055-EKC-WT-30c-a-1-p_S55_L001_R1_001
# 056-EKC-WT-30c-a-2-p_S56_L001_R1_001 056-EKC-WT-30c-a-2-p_S56_L001_R1_001
# 057-EKC-WT-30c-a-3-p_S57_L001_R1_001 057-EKC-WT-30c-a-3-p_S57_L001_R1_001
# 058-EKC-WT-30c-a-4-p_S58_L001_R1_001 058-EKC-WT-30c-a-4-p_S58_L001_R1_001
# 059-EKC-WT-30c-a-5-p_S59_L001_R1_001 059-EKC-WT-30c-a-5-p_S59_L001_R1_001
# 060-EKC-WT-30c-a-6-p_S60_L001_R1_001 060-EKC-WT-30c-a-6-p_S60_L001_R1_001
# 061-EKC-WT-30c-b-1-p_S61_L001_R1_001 061-EKC-WT-30c-b-1-p_S61_L001_R1_001
# 062-EKC-WT-30c-b-2-p_S62_L001_R1_001 062-EKC-WT-30c-b-2-p_S62_L001_R1_001
# 063-EKC-WT-30c-b-3-p_S63_L001_R1_001 063-EKC-WT-30c-b-3-p_S63_L001_R1_001
# 064-EKC-WT-30c-b-4-p_S64_L001_R1_001 064-EKC-WT-30c-b-4-p_S64_L001_R1_001
# 065-EKC-WT-30c-b-5-p_S65_L001_R1_001 065-EKC-WT-30c-b-5-p_S65_L001_R1_001
# 066-EKC-WT-30c-b-6-p_S66_L001_R1_001 066-EKC-WT-30c-b-6-p_S66_L001_R1_001
# 067-EKC-WT-37c-b-1-p_S67_L001_R1_001 067-EKC-WT-37c-b-1-p_S67_L001_R1_001
# 068-EKC-WT-37c-b-2-p_S68_L001_R1_001 068-EKC-WT-37c-b-2-p_S68_L001_R1_001
# 069-EKC-WT-37c-b-3-p_S69_L001_R1_001 069-EKC-WT-37c-b-3-p_S69_L001_R1_001
# 070-EKC-WT-37c-b-4-p_S70_L001_R1_001 070-EKC-WT-37c-b-4-p_S70_L001_R1_001
# 071-EKC-WT-37c-b-5-p_S71_L001_R1_001 071-EKC-WT-37c-b-5-p_S71_L001_R1_001
# 072-EKC-WT-37c-b-6-p_S72_L001_R1_001 072-EKC-WT-37c-b-6-p_S72_L001_R1_001
# 073-EKC-WT-45c-b-1-p_S73_L001_R1_001 073-EKC-WT-45c-b-1-p_S73_L001_R1_001
# 074-EKC-WT-45c-b-2-p_S74_L001_R1_001 074-EKC-WT-45c-b-2-p_S74_L001_R1_001
# 075-EKC-WT-45c-b-3-p_S75_L001_R1_001 075-EKC-WT-45c-b-3-p_S75_L001_R1_001
# 076-EKC-WT-45c-b-4-p_S76_L001_R1_001 076-EKC-WT-45c-b-4-p_S76_L001_R1_001
# 077-EKC-WT-45c-b-5-p_S77_L001_R1_001 077-EKC-WT-45c-b-5-p_S77_L001_R1_001
# 078-EKC-WT-45c-b-6-p_S78_L001_R1_001 078-EKC-WT-45c-b-6-p_S78_L001_R1_001
# 079-EKC-WT-50c-a-1-p_S79_L001_R1_001 079-EKC-WT-50c-a-1-p_S79_L001_R1_001
# 080-EKC-WT-50c-a-2-p_S80_L001_R1_001 080-EKC-WT-50c-a-2-p_S80_L001_R1_001
# 081-EKC-WT-50c-a-3-p_S81_L001_R1_001 081-EKC-WT-50c-a-3-p_S81_L001_R1_001
# 082-EKC-WT-50c-a-4-p_S82_L001_R1_001 082-EKC-WT-50c-a-4-p_S82_L001_R1_001
# 083-EKC-WT-50c-a-5-p_S83_L001_R1_001 083-EKC-WT-50c-a-5-p_S83_L001_R1_001
# 084-EKC-WT-50c-a-6-p_S84_L001_R1_001 084-EKC-WT-50c-a-6-p_S84_L001_R1_001
# 085-EKC-WT-50c-b-1-p_S85_L001_R1_001 085-EKC-WT-50c-b-1-p_S85_L001_R1_001
# 086-EKC-WT-50c-b-2-p_S86_L001_R1_001 086-EKC-WT-50c-b-2-p_S86_L001_R1_001
# 087-EKC-WT-50c-b-3-p_S87_L001_R1_001 087-EKC-WT-50c-b-3-p_S87_L001_R1_001
# 088-EKC-WT-50c-b-4-p_S88_L001_R1_001 088-EKC-WT-50c-b-4-p_S88_L001_R1_001
# 089-EKC-WT-50c-b-5-p_S89_L001_R1_001 089-EKC-WT-50c-b-5-p_S89_L001_R1_001
# 001-EKC-A8C-60c-a-1-p_S1_L001_R1_001 001-EKC-A8C-60c-a-1-p_S1_L001_R1_001
# 002-EKC-A8C-60c-a-2-p_S2_L001_R1_001 002-EKC-A8C-60c-a-2-p_S2_L001_R1_001
# 003-EKC-A8C-60c-a-3-p_S3_L001_R1_001 003-EKC-A8C-60c-a-3-p_S3_L001_R1_001
# 004-EKC-A8C-60c-a-4-p_S4_L001_R1_001 004-EKC-A8C-60c-a-4-p_S4_L001_R1_001
# 005-EKC-A8C-60c-a-5-p_S5_L001_R1_001 005-EKC-A8C-60c-a-5-p_S5_L001_R1_001
# 006-EKC-A8C-60c-a-6-p_S6_L001_R1_001 006-EKC-A8C-60c-a-6-p_S6_L001_R1_001
# 007-EKC-A8C-60c-b-1-p_S7_L001_R1_001 007-EKC-A8C-60c-b-1-p_S7_L001_R1_001
# 008-EKC-A8C-60c-b-2-p_S8_L001_R1_001 008-EKC-A8C-60c-b-2-p_S8_L001_R1_001
# 009-EKC-A8C-60c-b-3-p_S9_L001_R1_001 009-EKC-A8C-60c-b-3-p_S9_L001_R1_001
# 010-EKC-A8C-60c-b-4-p_S10_L001_R1_001 010-EKC-A8C-60c-b-4-p_S10_L001_R1_001
# 011-EKC-A8C-60c-b-5-p_S11_L001_R1_001 011-EKC-A8C-60c-b-5-p_S11_L001_R1_001
# 012-EKC-A8C-60c-b-6-p_S12_L001_R1_001 012-EKC-A8C-60c-b-6-p_S12_L001_R1_001
# 013-EKC-A8C-70c-a-1-p_S13_L001_R1_001 013-EKC-A8C-70c-a-1-p_S13_L001_R1_001
# 014-EKC-A8C-70c-a-2-p_S14_L001_R1_001 014-EKC-A8C-70c-a-2-p_S14_L001_R1_001
# 015-EKC-A8C-70c-a-3-p_S15_L001_R1_001 015-EKC-A8C-70c-a-3-p_S15_L001_R1_001
# 016-EKC-A8C-70c-a-4-p_S16_L001_R1_001 016-EKC-A8C-70c-a-4-p_S16_L001_R1_001
# 017-EKC-A8C-70c-a-5-p_S17_L001_R1_001 017-EKC-A8C-70c-a-5-p_S17_L001_R1_001
# 018-EKC-A8C-70c-a-6-p_S18_L001_R1_001 018-EKC-A8C-70c-a-6-p_S18_L001_R1_001
# 019-EKC-A8C-70c-b-1-p_S19_L001_R1_001 019-EKC-A8C-70c-b-1-p_S19_L001_R1_001
# 020-EKC-A8C-70c-b-2-p_S20_L001_R1_001 020-EKC-A8C-70c-b-2-p_S20_L001_R1_001
# 021-EKC-A8C-70c-b-3-p_S21_L001_R1_001 021-EKC-A8C-70c-b-3-p_S21_L001_R1_001
# 022-EKC-A8C-70c-b-4-p_S22_L001_R1_001 022-EKC-A8C-70c-b-4-p_S22_L001_R1_001
# 023-EKC-A8C-70c-b-5-p_S23_L001_R1_001 023-EKC-A8C-70c-b-5-p_S23_L001_R1_001
# 024-EKC-A8C-70c-b-6-p_S24_L001_R1_001 024-EKC-A8C-70c-b-6-p_S24_L001_R1_001
# 025-EKC-A8C-75c-a-1-p_S25_L001_R1_001 025-EKC-A8C-75c-a-1-p_S25_L001_R1_001
# 026-EKC-A8C-75c-a-2-p_S26_L001_R1_001 026-EKC-A8C-75c-a-2-p_S26_L001_R1_001
# 027-EKC-A8C-75c-a-3-p_S27_L001_R1_001 027-EKC-A8C-75c-a-3-p_S27_L001_R1_001
# 028-EKC-A8C-75c-a-4-p_S28_L001_R1_001 028-EKC-A8C-75c-a-4-p_S28_L001_R1_001
# 029-EKC-A8C-75c-a-5-p_S29_L001_R1_001 029-EKC-A8C-75c-a-5-p_S29_L001_R1_001
# 030-EKC-A8C-75c-a-6-p_S30_L001_R1_001 030-EKC-A8C-75c-a-6-p_S30_L001_R1_001
# 031-EKC-A8C-75c-b-1-p_S31_L001_R1_001 031-EKC-A8C-75c-b-1-p_S31_L001_R1_001
# 032-EKC-A8C-75c-b-2-p_S32_L001_R1_001 032-EKC-A8C-75c-b-2-p_S32_L001_R1_001
# 033-EKC-A8C-75c-b-3-p_S33_L001_R1_001 033-EKC-A8C-75c-b-3-p_S33_L001_R1_001
# 034-EKC-A8C-75c-b-4-p_S34_L001_R1_001 034-EKC-A8C-75c-b-4-p_S34_L001_R1_001
# 035-EKC-A8C-75c-b-5-p_S35_L001_R1_001 035-EKC-A8C-75c-b-5-p_S35_L001_R1_001
# 036-EKC-A8C-75c-b-6-p_S36_L001_R1_001 036-EKC-A8C-75c-b-6-p_S36_L001_R1_001
# 037-EKC-A8C-80c-a-1-p_S37_L001_R1_001 037-EKC-A8C-80c-a-1-p_S37_L001_R1_001
# 038-EKC-A8C-80c-a-2-p_S38_L001_R1_001 038-EKC-A8C-80c-a-2-p_S38_L001_R1_001
# 039-EKC-A8C-80c-a-3-p_S39_L001_R1_001 039-EKC-A8C-80c-a-3-p_S39_L001_R1_001
# 040-EKC-A8C-80c-a-4-p_S40_L001_R1_001 040-EKC-A8C-80c-a-4-p_S40_L001_R1_001
# 041-EKC-A8C-80c-a-5-p_S41_L001_R1_001 041-EKC-A8C-80c-a-5-p_S41_L001_R1_001
# 042-EKC-A8C-80c-a-6-p_S42_L001_R1_001 042-EKC-A8C-80c-a-6-p_S42_L001_R1_001
# 043-EKC-A8C-80c-b-1-p_S43_L001_R1_001 043-EKC-A8C-80c-b-1-p_S43_L001_R1_001
# 044-EKC-A8C-80c-b-2-p_S44_L001_R1_001 044-EKC-A8C-80c-b-2-p_S44_L001_R1_001
# 045-EKC-A8C-80c-b-3-p_S45_L001_R1_001 045-EKC-A8C-80c-b-3-p_S45_L001_R1_001
# 046-EKC-A8C-80c-b-4-p_S46_L001_R1_001 046-EKC-A8C-80c-b-4-p_S46_L001_R1_001
# 047-EKC-A8C-80c-b-5-p_S47_L001_R1_001 047-EKC-A8C-80c-b-5-p_S47_L001_R1_001
# 048-EKC-A8C-80c-b-6-p_S48_L001_R1_001 048-EKC-A8C-80c-b-6-p_S48_L001_R1_001
# 049-EKC-A8C-25c-b-1-p_S49_L001_R1_001 049-EKC-A8C-25c-b-1-p_S49_L001_R1_001
# 050-EKC-A8C-25c-b-2-p_S50_L001_R1_001 050-EKC-A8C-25c-b-2-p_S50_L001_R1_001
# 051-EKC-A8C-25c-b-3-p_S51_L001_R1_001 051-EKC-A8C-25c-b-3-p_S51_L001_R1_001
# 052-EKC-A8C-25c-b-4-p_S52_L001_R1_001 052-EKC-A8C-25c-b-4-p_S52_L001_R1_001
# 053-EKC-A8C-25c-b-5-p_S53_L001_R1_001 053-EKC-A8C-25c-b-5-p_S53_L001_R1_001
# 054-EKC-A8C-25c-b-6-p_S54_L001_R1_001 054-EKC-A8C-25c-b-6-p_S54_L001_R1_001
# 055-EKC-A8C-30c-a-1-p_S55_L001_R1_001 055-EKC-A8C-30c-a-1-p_S55_L001_R1_001
# 056-EKC-A8C-30c-a-2-p_S56_L001_R1_001 056-EKC-A8C-30c-a-2-p_S56_L001_R1_001
# 057-EKC-A8C-30c-a-3-p_S57_L001_R1_001 057-EKC-A8C-30c-a-3-p_S57_L001_R1_001
# 058-EKC-A8C-30c-a-4-p_S58_L001_R1_001 058-EKC-A8C-30c-a-4-p_S58_L001_R1_001
# 059-EKC-A8C-30c-a-5-p_S59_L001_R1_001 059-EKC-A8C-30c-a-5-p_S59_L001_R1_001
# 060-EKC-A8C-30c-a-6-p_S60_L001_R1_001 060-EKC-A8C-30c-a-6-p_S60_L001_R1_001
# 061-EKC-A8C-30c-b-1-p_S61_L001_R1_001 061-EKC-A8C-30c-b-1-p_S61_L001_R1_001
# 062-EKC-A8C-30c-b-2-p_S62_L001_R1_001 062-EKC-A8C-30c-b-2-p_S62_L001_R1_001
# 063-EKC-A8C-30c-b-3-p_S63_L001_R1_001 063-EKC-A8C-30c-b-3-p_S63_L001_R1_001
# 064-EKC-A8C-30c-b-4-p_S64_L001_R1_001 064-EKC-A8C-30c-b-4-p_S64_L001_R1_001
# 065-EKC-A8C-30c-b-5-p_S65_L001_R1_001 065-EKC-A8C-30c-b-5-p_S65_L001_R1_001
# 066-EKC-A8C-30c-b-6-p_S66_L001_R1_001 066-EKC-A8C-30c-b-6-p_S66_L001_R1_001
# 067-EKC-A8C-37c-b-1-p_S67_L001_R1_001 067-EKC-A8C-37c-b-1-p_S67_L001_R1_001
# 068-EKC-A8C-37c-b-2-p_S68_L001_R1_001 068-EKC-A8C-37c-b-2-p_S68_L001_R1_001
# 069-EKC-A8C-37c-b-3-p_S69_L001_R1_001 069-EKC-A8C-37c-b-3-p_S69_L001_R1_001
# 070-EKC-A8C-37c-b-4-p_S70_L001_R1_001 070-EKC-A8C-37c-b-4-p_S70_L001_R1_001
# 071-EKC-A8C-37c-b-5-p_S71_L001_R1_001 071-EKC-A8C-37c-b-5-p_S71_L001_R1_001
# 072-EKC-A8C-37c-b-6-p_S72_L001_R1_001 072-EKC-A8C-37c-b-6-p_S72_L001_R1_001
# 073-EKC-A8C-45c-b-1-p_S73_L001_R1_001 073-EKC-A8C-45c-b-1-p_S73_L001_R1_001
# 074-EKC-A8C-45c-b-2-p_S74_L001_R1_001 074-EKC-A8C-45c-b-2-p_S74_L001_R1_001
# 075-EKC-A8C-45c-b-3-p_S75_L001_R1_001 075-EKC-A8C-45c-b-3-p_S75_L001_R1_001
# 076-EKC-A8C-45c-b-4-p_S76_L001_R1_001 076-EKC-A8C-45c-b-4-p_S76_L001_R1_001
# 077-EKC-A8C-45c-b-5-p_S77_L001_R1_001 077-EKC-A8C-45c-b-5-p_S77_L001_R1_001
# 078-EKC-A8C-45c-b-6-p_S78_L001_R1_001 078-EKC-A8C-45c-b-6-p_S78_L001_R1_001
# 079-EKC-A8C-50c-a-1-p_S79_L001_R1_001 079-EKC-A8C-50c-a-1-p_S79_L001_R1_001
# 080-EKC-A8C-50c-a-2-p_S80_L001_R1_001 080-EKC-A8C-50c-a-2-p_S80_L001_R1_001
# 081-EKC-A8C-50c-a-3-p_S81_L001_R1_001 081-EKC-A8C-50c-a-3-p_S81_L001_R1_001
# 082-EKC-A8C-50c-a-4-p_S82_L001_R1_001 082-EKC-A8C-50c-a-4-p_S82_L001_R1_001
# 083-EKC-A8C-50c-a-5-p_S83_L001_R1_001 083-EKC-A8C-50c-a-5-p_S83_L001_R1_001
# 084-EKC-A8C-50c-a-6-p_S84_L001_R1_001 084-EKC-A8C-50c-a-6-p_S84_L001_R1_001
# 085-EKC-A8C-50c-b-1-p_S85_L001_R1_001 085-EKC-A8C-50c-b-1-p_S85_L001_R1_001
# 086-EKC-A8C-50c-b-2-p_S86_L001_R1_001 086-EKC-A8C-50c-b-2-p_S86_L001_R1_001
# 087-EKC-A8C-50c-b-3-p_S87_L001_R1_001 087-EKC-A8C-50c-b-3-p_S87_L001_R1_001
# 088-EKC-A8C-50c-b-4-p_S88_L001_R1_001 088-EKC-A8C-50c-b-4-p_S88_L001_R1_001
# 089-EKC-A8C-50c-b-5-p_S89_L001_R1_001 089-EKC-A8C-50c-b-5-p_S89_L001_R1_001
# 090-EKC-A8C-50c-b-6-p_S90_L001_R1_001 090-EKC-A8C-50c-b-6-p_S90_L001_R1_001
# 091-EKC-A8C-30c-b-6-m_S91_L001_R1_001 091-EKC-A8C-30c-b-6-m_S91_L001_R1_001
# 092-EKC-A8C-37c-b-6-m_S92_L001_R1_001 092-EKC-A8C-37c-b-6-m_S92_L001_R1_001
# 093-EKC-A8C-45c-b-6-m_S93_L001_R1_001 093-EKC-A8C-45c-b-6-m_S93_L001_R1_001
# 094-EKC-A8C-50c-a-6-m_S94_L001_R1_001 094-EKC-A8C-50c-a-6-m_S94_L001_R1_001
# 095-EKC-A8C-50c-b-6-m_S95_L001_R1_001 095-EKC-A8C-50c-b-6-m_S95_L001_R1_001
# 096-EKC-A8C-60c-a-6-m_S96_L001_R1_001 096-EKC-A8C-60c-a-6-m_S96_L001_R1_001
# 001-fourU-WT-65c-a-1-p_S1_L001_R1_001 001-fourU-WT-65c-a-1-p_S1_L001_R1_001
# fmod_calc_runs_2/000000000821 ./001-fourU-WT-65c-a-1-p_S1_L001_R1_001.fastq.gz 001-fourU-WT-65c-a-1-p_S1_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 002-fourU-WT-65c-a-2-p_S2_L001_R1_001 002-fourU-WT-65c-a-2-p_S2_L001_R1_001
# fmod_calc_runs_2/000000000832 ./002-fourU-WT-65c-a-2-p_S2_L001_R1_001.fastq.gz 002-fourU-WT-65c-a-2-p_S2_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 003-fourU-WT-65c-a-3-p_S3_L001_R1_001 003-fourU-WT-65c-a-3-p_S3_L001_R1_001
# fmod_calc_runs_2/000000000843 ./003-fourU-WT-65c-a-3-p_S3_L001_R1_001.fastq.gz 003-fourU-WT-65c-a-3-p_S3_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 004-fourU-WT-65c-a-4-p_S4_L001_R1_001 004-fourU-WT-65c-a-4-p_S4_L001_R1_001
# fmod_calc_runs_2/000000000854 ./004-fourU-WT-65c-a-4-p_S4_L001_R1_001.fastq.gz 004-fourU-WT-65c-a-4-p_S4_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 005-fourU-WT-65c-a-5-p_S5_L001_R1_001 005-fourU-WT-65c-a-5-p_S5_L001_R1_001
# fmod_calc_runs_2/000000000864 ./005-fourU-WT-65c-a-5-p_S5_L001_R1_001.fastq.gz 005-fourU-WT-65c-a-5-p_S5_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 006-fourU-WT-65c-a-6-p_S6_L001_R1_001 006-fourU-WT-65c-a-6-p_S6_L001_R1_001
# fmod_calc_runs_2/000000000877 ./006-fourU-WT-65c-a-6-p_S6_L001_R1_001.fastq.gz 006-fourU-WT-65c-a-6-p_S6_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 007-fourU-WT-65c-b-1-p_S7_L001_R1_001 007-fourU-WT-65c-b-1-p_S7_L001_R1_001
# fmod_calc_runs_2/000000000887 ./007-fourU-WT-65c-b-1-p_S7_L001_R1_001.fastq.gz 007-fourU-WT-65c-b-1-p_S7_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 008-fourU-WT-65c-b-2-p_S8_L001_R1_001 008-fourU-WT-65c-b-2-p_S8_L001_R1_001
# fmod_calc_runs_2/000000000898 ./008-fourU-WT-65c-b-2-p_S8_L001_R1_001.fastq.gz 008-fourU-WT-65c-b-2-p_S8_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 009-fourU-WT-65c-b-3-p_S9_L001_R1_001 009-fourU-WT-65c-b-3-p_S9_L001_R1_001
# fmod_calc_runs_2/000000000908 ./009-fourU-WT-65c-b-3-p_S9_L001_R1_001.fastq.gz 009-fourU-WT-65c-b-3-p_S9_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 010-fourU-WT-65c-b-4-p_S10_L001_R1_001 010-fourU-WT-65c-b-4-p_S10_L001_R1_001
# fmod_calc_runs_2/000000000822 ./010-fourU-WT-65c-b-4-p_S10_L001_R1_001.fastq.gz 010-fourU-WT-65c-b-4-p_S10_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 011-fourU-WT-65c-b-5-p_S11_L001_R1_001 011-fourU-WT-65c-b-5-p_S11_L001_R1_001
# fmod_calc_runs_2/000000000823 ./011-fourU-WT-65c-b-5-p_S11_L001_R1_001.fastq.gz 011-fourU-WT-65c-b-5-p_S11_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 012-fourU-WT-65c-b-6-p_S12_L001_R1_001 012-fourU-WT-65c-b-6-p_S12_L001_R1_001
# fmod_calc_runs_2/000000000824 ./012-fourU-WT-65c-b-6-p_S12_L001_R1_001.fastq.gz 012-fourU-WT-65c-b-6-p_S12_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 013-fourU-WT-70c-a-1-p_S13_L001_R1_001 013-fourU-WT-70c-a-1-p_S13_L001_R1_001
# fmod_calc_runs_2/000000000825 ./013-fourU-WT-70c-a-1-p_S13_L001_R1_001.fastq.gz 013-fourU-WT-70c-a-1-p_S13_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 014-fourU-WT-70c-a-2-p_S14_L001_R1_001 014-fourU-WT-70c-a-2-p_S14_L001_R1_001
# fmod_calc_runs_2/000000000826 ./014-fourU-WT-70c-a-2-p_S14_L001_R1_001.fastq.gz 014-fourU-WT-70c-a-2-p_S14_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 015-fourU-WT-70c-a-3-p_S15_L001_R1_001 015-fourU-WT-70c-a-3-p_S15_L001_R1_001
# fmod_calc_runs_2/000000000827 ./015-fourU-WT-70c-a-3-p_S15_L001_R1_001.fastq.gz 015-fourU-WT-70c-a-3-p_S15_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 016-fourU-WT-70c-a-4-p_S16_L001_R1_001 016-fourU-WT-70c-a-4-p_S16_L001_R1_001
# fmod_calc_runs_2/000000000828 ./016-fourU-WT-70c-a-4-p_S16_L001_R1_001.fastq.gz 016-fourU-WT-70c-a-4-p_S16_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 017-fourU-WT-70c-a-5-p_S17_L001_R1_001 017-fourU-WT-70c-a-5-p_S17_L001_R1_001
# fmod_calc_runs_2/000000000829 ./017-fourU-WT-70c-a-5-p_S17_L001_R1_001.fastq.gz 017-fourU-WT-70c-a-5-p_S17_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 018-fourU-WT-70c-a-6-p_S18_L001_R1_001 018-fourU-WT-70c-a-6-p_S18_L001_R1_001
# fmod_calc_runs_2/000000000830 ./018-fourU-WT-70c-a-6-p_S18_L001_R1_001.fastq.gz 018-fourU-WT-70c-a-6-p_S18_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 019-fourU-WT-70c-b-1-p_S19_L001_R1_001 019-fourU-WT-70c-b-1-p_S19_L001_R1_001
# fmod_calc_runs_2/000000000831 ./019-fourU-WT-70c-b-1-p_S19_L001_R1_001.fastq.gz 019-fourU-WT-70c-b-1-p_S19_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 020-fourU-WT-70c-b-2-p_S20_L001_R1_001 020-fourU-WT-70c-b-2-p_S20_L001_R1_001
# fmod_calc_runs_2/000000000833 ./020-fourU-WT-70c-b-2-p_S20_L001_R1_001.fastq.gz 020-fourU-WT-70c-b-2-p_S20_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 021-fourU-WT-70c-b-3-p_S21_L001_R1_001 021-fourU-WT-70c-b-3-p_S21_L001_R1_001
# fmod_calc_runs_2/000000000834 ./021-fourU-WT-70c-b-3-p_S21_L001_R1_001.fastq.gz 021-fourU-WT-70c-b-3-p_S21_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 022-fourU-WT-70c-b-4-p_S22_L001_R1_001 022-fourU-WT-70c-b-4-p_S22_L001_R1_001
# fmod_calc_runs_2/000000000835 ./022-fourU-WT-70c-b-4-p_S22_L001_R1_001.fastq.gz 022-fourU-WT-70c-b-4-p_S22_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 023-fourU-WT-70c-b-5-p_S23_L001_R1_001 023-fourU-WT-70c-b-5-p_S23_L001_R1_001
# fmod_calc_runs_2/000000000836 ./023-fourU-WT-70c-b-5-p_S23_L001_R1_001.fastq.gz 023-fourU-WT-70c-b-5-p_S23_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 024-fourU-WT-70c-b-6-p_S24_L001_R1_001 024-fourU-WT-70c-b-6-p_S24_L001_R1_001
# fmod_calc_runs_2/000000000837 ./024-fourU-WT-70c-b-6-p_S24_L001_R1_001.fastq.gz 024-fourU-WT-70c-b-6-p_S24_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 025-fourU-WT-75c-a-1-p_S25_L001_R1_001 025-fourU-WT-75c-a-1-p_S25_L001_R1_001
# fmod_calc_runs_2/000000000838 ./025-fourU-WT-75c-a-1-p_S25_L001_R1_001.fastq.gz 025-fourU-WT-75c-a-1-p_S25_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 026-fourU-WT-75c-a-2-p_S26_L001_R1_001 026-fourU-WT-75c-a-2-p_S26_L001_R1_001
# fmod_calc_runs_2/000000000839 ./026-fourU-WT-75c-a-2-p_S26_L001_R1_001.fastq.gz 026-fourU-WT-75c-a-2-p_S26_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 027-fourU-WT-75c-a-3-p_S27_L001_R1_001 027-fourU-WT-75c-a-3-p_S27_L001_R1_001
# fmod_calc_runs_2/000000000840 ./027-fourU-WT-75c-a-3-p_S27_L001_R1_001.fastq.gz 027-fourU-WT-75c-a-3-p_S27_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 028-fourU-WT-75c-a-4-p_S28_L001_R1_001 028-fourU-WT-75c-a-4-p_S28_L001_R1_001
# fmod_calc_runs_2/000000000841 ./028-fourU-WT-75c-a-4-p_S28_L001_R1_001.fastq.gz 028-fourU-WT-75c-a-4-p_S28_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 029-fourU-WT-75c-a-5-p_S29_L001_R1_001 029-fourU-WT-75c-a-5-p_S29_L001_R1_001
# fmod_calc_runs_2/000000000842 ./029-fourU-WT-75c-a-5-p_S29_L001_R1_001.fastq.gz 029-fourU-WT-75c-a-5-p_S29_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 030-fourU-WT-75c-a-6-p_S30_L001_R1_001 030-fourU-WT-75c-a-6-p_S30_L001_R1_001
# fmod_calc_runs_2/000000000844 ./030-fourU-WT-75c-a-6-p_S30_L001_R1_001.fastq.gz 030-fourU-WT-75c-a-6-p_S30_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 031-fourU-WT-75c-b-1-p_S31_L001_R1_001 031-fourU-WT-75c-b-1-p_S31_L001_R1_001
# fmod_calc_runs_2/000000000845 ./031-fourU-WT-75c-b-1-p_S31_L001_R1_001.fastq.gz 031-fourU-WT-75c-b-1-p_S31_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 032-fourU-WT-75c-b-2-p_S32_L001_R1_001 032-fourU-WT-75c-b-2-p_S32_L001_R1_001
# fmod_calc_runs_2/000000000846 ./032-fourU-WT-75c-b-2-p_S32_L001_R1_001.fastq.gz 032-fourU-WT-75c-b-2-p_S32_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 033-fourU-WT-75c-b-3-p_S33_L001_R1_001 033-fourU-WT-75c-b-3-p_S33_L001_R1_001
# fmod_calc_runs_2/000000000847 ./033-fourU-WT-75c-b-3-p_S33_L001_R1_001.fastq.gz 033-fourU-WT-75c-b-3-p_S33_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 034-fourU-WT-75c-b-4-p_S34_L001_R1_001 034-fourU-WT-75c-b-4-p_S34_L001_R1_001
# fmod_calc_runs_2/000000000849 ./034-fourU-WT-75c-b-4-p_S34_L001_R1_001.fastq.gz 034-fourU-WT-75c-b-4-p_S34_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 035-fourU-WT-75c-b-5-p_S35_L001_R1_001 035-fourU-WT-75c-b-5-p_S35_L001_R1_001
# fmod_calc_runs_2/000000000848 ./035-fourU-WT-75c-b-5-p_S35_L001_R1_001.fastq.gz 035-fourU-WT-75c-b-5-p_S35_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 036-fourU-WT-75c-b-6-p_S36_L001_R1_001 036-fourU-WT-75c-b-6-p_S36_L001_R1_001
# fmod_calc_runs_2/000000000850 ./036-fourU-WT-75c-b-6-p_S36_L001_R1_001.fastq.gz 036-fourU-WT-75c-b-6-p_S36_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 037-fourU-WT-80c-a-1-p_S37_L001_R1_001 037-fourU-WT-80c-a-1-p_S37_L001_R1_001
# fmod_calc_runs_2/000000000851 ./037-fourU-WT-80c-a-1-p_S37_L001_R1_001.fastq.gz 037-fourU-WT-80c-a-1-p_S37_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 038-fourU-WT-80c-a-2-p_S38_L001_R1_001 038-fourU-WT-80c-a-2-p_S38_L001_R1_001
# fmod_calc_runs_2/000000000853 ./038-fourU-WT-80c-a-2-p_S38_L001_R1_001.fastq.gz 038-fourU-WT-80c-a-2-p_S38_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 039-fourU-WT-80c-a-3-p_S39_L001_R1_001 039-fourU-WT-80c-a-3-p_S39_L001_R1_001
# fmod_calc_runs_2/000000000852 ./039-fourU-WT-80c-a-3-p_S39_L001_R1_001.fastq.gz 039-fourU-WT-80c-a-3-p_S39_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 040-fourU-WT-80c-a-4-p_S40_L001_R1_001 040-fourU-WT-80c-a-4-p_S40_L001_R1_001
# fmod_calc_runs_2/000000000855 ./040-fourU-WT-80c-a-4-p_S40_L001_R1_001.fastq.gz 040-fourU-WT-80c-a-4-p_S40_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 041-fourU-WT-80c-a-5-p_S41_L001_R1_001 041-fourU-WT-80c-a-5-p_S41_L001_R1_001
# fmod_calc_runs_2/000000000856 ./041-fourU-WT-80c-a-5-p_S41_L001_R1_001.fastq.gz 041-fourU-WT-80c-a-5-p_S41_L001_R1_001.fastq.gz
# Sample name does not match R1 file, skipping...
# 042-fourU-WT-80c-a-6-p_S42_L001_R1_001 042-fourU-WT-80c-a-6-p_S42_L001_R1_001
# ...
# 028-HIV-UUCG-ES-75c-a-4-p_S28_L001_R1_001 028-HIV-UUCG-ES-75c-a-4-p_S28_L001_R1_001
# 029-HIV-UUCG-ES-75c-a-5-p_S29_L001_R1_001 029-HIV-UUCG-ES-75c-a-5-p_S29_L001_R1_001
# 030-HIV-UUCG-ES-75c-a-6-p_S30_L001_R1_001 030-HIV-UUCG-ES-75c-a-6-p_S30_L001_R1_001
# 031-HIV-UUCG-ES-75c-b-1-p_S31_L001_R1_001 031-HIV-UUCG-ES-75c-b-1-p_S31_L001_R1_001
# 032-HIV-UUCG-ES-75c-b-2-p_S32_L001_R1_001 032-HIV-UUCG-ES-75c-b-2-p_S32_L001_R1_001
# 033-HIV-UUCG-ES-75c-b-3-p_S33_L001_R1_001 033-HIV-UUCG-ES-75c-b-3-p_S33_L001_R1_001
# 034-HIV-UUCG-ES-75c-b-4-p_S34_L001_R1_001 034-HIV-UUCG-ES-75c-b-4-p_S34_L001_R1_001
# 035-HIV-UUCG-ES-75c-b-5-p_S35_L001_R1_001 035-HIV-UUCG-ES-75c-b-5-p_S35_L001_R1_001
# 036-HIV-UUCG-ES-75c-b-6-p_S36_L001_R1_001 036-HIV-UUCG-ES-75c-b-6-p_S36_L001_R1_001
# 037-HIV-UUCG-ES-80c-a-1-p_S37_L001_R1_001 037-HIV-UUCG-ES-80c-a-1-p_S37_L001_R1_001
# 038-HIV-UUCG-ES-80c-a-2-p_S38_L001_R1_001 038-HIV-UUCG-ES-80c-a-2-p_S38_L001_R1_001
# 039-HIV-UUCG-ES-80c-a-3-p_S39_L001_R1_001 039-HIV-UUCG-ES-80c-a-3-p_S39_L001_R1_001
# 040-HIV-UUCG-ES-80c-a-4-p_S40_L001_R1_001 040-HIV-UUCG-ES-80c-a-4-p_S40_L001_R1_001
# 041-HIV-UUCG-ES-80c-a-5-p_S41_L001_R1_001 041-HIV-UUCG-ES-80c-a-5-p_S41_L001_R1_001
# 042-HIV-UUCG-ES-80c-a-6-p_S42_L001_R1_001 042-HIV-UUCG-ES-80c-a-6-p_S42_L001_R1_001
# 043-HIV-UUCG-ES-80c-b-1-p_S43_L001_R1_001 043-HIV-UUCG-ES-80c-b-1-p_S43_L001_R1_001
# 044-HIV-UUCG-ES-80c-b-2-p_S44_L001_R1_001 044-HIV-UUCG-ES-80c-b-2-p_S44_L001_R1_001
# 045-HIV-UUCG-ES-80c-b-3-p_S45_L001_R1_001 045-HIV-UUCG-ES-80c-b-3-p_S45_L001_R1_001
# 046-HIV-UUCG-ES-80c-b-4-p_S46_L001_R1_001 046-HIV-UUCG-ES-80c-b-4-p_S46_L001_R1_001
# 047-HIV-UUCG-ES-80c-b-5-p_S47_L001_R1_001 047-HIV-UUCG-ES-80c-b-5-p_S47_L001_R1_001
# 048-HIV-UUCG-ES-80c-b-6-p_S48_L001_R1_001 048-HIV-UUCG-ES-80c-b-6-p_S48_L001_R1_001
# 049-HIV-A35G-25c-a-1-p_S49_L001_R1_001 049-HIV-A35G-25c-a-1-p_S49_L001_R1_001
# 050-HIV-A35G-25c-a-2-p_S50_L001_R1_001 050-HIV-A35G-25c-a-2-p_S50_L001_R1_001
# 051-HIV-A35G-25c-a-3-p_S51_L001_R1_001 051-HIV-A35G-25c-a-3-p_S51_L001_R1_001
# 052-HIV-A35G-25c-a-4-p_S52_L001_R1_001 052-HIV-A35G-25c-a-4-p_S52_L001_R1_001
# 053-HIV-A35G-25c-a-5-p_S53_L001_R1_001 053-HIV-A35G-25c-a-5-p_S53_L001_R1_001
# 054-HIV-A35G-25c-a-6-p_S54_L001_R1_001 054-HIV-A35G-25c-a-6-p_S54_L001_R1_001
# 055-HIV-A35G-25c-b-1-p_S55_L001_R1_001 055-HIV-A35G-25c-b-1-p_S55_L001_R1_001
# 056-HIV-A35G-25c-b-2-p_S56_L001_R1_001 056-HIV-A35G-25c-b-2-p_S56_L001_R1_001
# 057-HIV-A35G-25c-b-3-p_S57_L001_R1_001 057-HIV-A35G-25c-b-3-p_S57_L001_R1_001
# 058-HIV-A35G-25c-b-4-p_S58_L001_R1_001 058-HIV-A35G-25c-b-4-p_S58_L001_R1_001
# 059-HIV-A35G-25c-b-5-p_S59_L001_R1_001 059-HIV-A35G-25c-b-5-p_S59_L001_R1_001
# 060-HIV-A35G-25c-b-6-p_S60_L001_R1_001 060-HIV-A35G-25c-b-6-p_S60_L001_R1_001
# 061-HIV-A35G-70c-a-1-p_S61_L001_R1_001 061-HIV-A35G-70c-a-1-p_S61_L001_R1_001
# 062-HIV-A35G-70c-a-2-p_S62_L001_R1_001 062-HIV-A35G-70c-a-2-p_S62_L001_R1_001
# 063-HIV-A35G-70c-a-3-p_S63_L001_R1_001 063-HIV-A35G-70c-a-3-p_S63_L001_R1_001
# 064-HIV-A35G-70c-a-4-p_S64_L001_R1_001 064-HIV-A35G-70c-a-4-p_S64_L001_R1_001
# 065-HIV-A35G-70c-a-5-p_S65_L001_R1_001 065-HIV-A35G-70c-a-5-p_S65_L001_R1_001
# 066-HIV-A35G-70c-a-6-p_S66_L001_R1_001 066-HIV-A35G-70c-a-6-p_S66_L001_R1_001
# 067-HIV-A35G-70c-b-1-p_S67_L001_R1_001 067-HIV-A35G-70c-b-1-p_S67_L001_R1_001
# 068-HIV-A35G-70c-b-2-p_S68_L001_R1_001 068-HIV-A35G-70c-b-2-p_S68_L001_R1_001
# 069-HIV-A35G-70c-b-3-p_S69_L001_R1_001 069-HIV-A35G-70c-b-3-p_S69_L001_R1_001
# 070-HIV-A35G-70c-b-4-p_S70_L001_R1_001 070-HIV-A35G-70c-b-4-p_S70_L001_R1_001
# 071-HIV-A35G-70c-b-5-p_S71_L001_R1_001 071-HIV-A35G-70c-b-5-p_S71_L001_R1_001
# 072-HIV-A35G-70c-b-6-p_S72_L001_R1_001 072-HIV-A35G-70c-b-6-p_S72_L001_R1_001
# 073-HIV-A35G-75c-a-1-p_S73_L001_R1_001 073-HIV-A35G-75c-a-1-p_S73_L001_R1_001
# 074-HIV-A35G-75c-a-2-p_S74_L001_R1_001 074-HIV-A35G-75c-a-2-p_S74_L001_R1_001
# 075-HIV-A35G-75c-a-3-p_S75_L001_R1_001 075-HIV-A35G-75c-a-3-p_S75_L001_R1_001
# 076-HIV-A35G-75c-a-4-p_S76_L001_R1_001 076-HIV-A35G-75c-a-4-p_S76_L001_R1_001
# 077-HIV-A35G-75c-a-5-p_S77_L001_R1_001 077-HIV-A35G-75c-a-5-p_S77_L001_R1_001
# 078-HIV-A35G-75c-a-6-p_S78_L001_R1_001 078-HIV-A35G-75c-a-6-p_S78_L001_R1_001
# 079-HIV-A35G-75c-b-1-p_S79_L001_R1_001 079-HIV-A35G-75c-b-1-p_S79_L001_R1_001
# 080-HIV-A35G-75c-b-2-p_S80_L001_R1_001 080-HIV-A35G-75c-b-2-p_S80_L001_R1_001
# 081-HIV-A35G-75c-b-3-p_S81_L001_R1_001 081-HIV-A35G-75c-b-3-p_S81_L001_R1_001
# 082-HIV-A35G-75c-b-4-p_S82_L001_R1_001 082-HIV-A35G-75c-b-4-p_S82_L001_R1_001
# 083-HIV-A35G-75c-b-5-p_S83_L001_R1_001 083-HIV-A35G-75c-b-5-p_S83_L001_R1_001
# 084-HIV-A35G-75c-b-6-p_S84_L001_R1_001 084-HIV-A35G-75c-b-6-p_S84_L001_R1_001
# 085-HIV-A35G-80c-a-1-p_S85_L001_R1_001 085-HIV-A35G-80c-a-1-p_S85_L001_R1_001
# 086-HIV-A35G-80c-a-2-p_S86_L001_R1_001 086-HIV-A35G-80c-a-2-p_S86_L001_R1_001
# 087-HIV-A35G-80c-a-3-p_S87_L001_R1_001 087-HIV-A35G-80c-a-3-p_S87_L001_R1_001
# 088-HIV-A35G-80c-a-4-p_S88_L001_R1_001 088-HIV-A35G-80c-a-4-p_S88_L001_R1_001
# 089-HIV-A35G-80c-a-5-p_S89_L001_R1_001 089-HIV-A35G-80c-a-5-p_S89_L001_R1_001
# 090-HIV-A35G-80c-a-6-p_S90_L001_R1_001 090-HIV-A35G-80c-a-6-p_S90_L001_R1_001
# 091-HIV-A35G-80c-b-6-p_S91_L001_R1_001 091-HIV-A35G-80c-b-6-p_S91_L001_R1_001
# 092-HIV-A35G-80c-b-6-p_S92_L001_R1_001 092-HIV-A35G-80c-b-6-p_S92_L001_R1_001
# 093-HIV-A35G-80c-b-6-p_S93_L001_R1_001 093-HIV-A35G-80c-b-6-p_S93_L001_R1_001
# 094-HIV-A35G-80c-b-6-p_S94_L001_R1_001 094-HIV-A35G-80c-b-6-p_S94_L001_R1_001
# 095-HIV-A35G-80c-b-6-p_S95_L001_R1_001 095-HIV-A35G-80c-b-6-p_S95_L001_R1_001
# 096-HIV-A35G-80c-b-6-p_S96_L001_R1_001 096-HIV-A35G-80c-b-6-p_S96_L001_R1_001
# 001-HIV-C30U-25c-a-1-p_S1_L001_R1_001 001-HIV-C30U-25c-a-1-p_S1_L001_R1_001
# 002-HIV-C30U-25c-a-2-p_S2_L001_R1_001 002-HIV-C30U-25c-a-2-p_S2_L001_R1_001
# 003-HIV-C30U-25c-a-3-p_S3_L001_R1_001 003-HIV-C30U-25c-a-3-p_S3_L001_R1_001
# 004-HIV-C30U-25c-a-4-p_S4_L001_R1_001 004-HIV-C30U-25c-a-4-p_S4_L001_R1_001
# 005-HIV-C30U-25c-a-5-p_S5_L001_R1_001 005-HIV-C30U-25c-a-5-p_S5_L001_R1_001
# 006-HIV-C30U-25c-a-6-p_S6_L001_R1_001 006-HIV-C30U-25c-a-6-p_S6_L001_R1_001
# 007-HIV-C30U-25c-b-1-p_S7_L001_R1_001 007-HIV-C30U-25c-b-1-p_S7_L001_R1_001
# 008-HIV-C30U-25c-b-2-p_S8_L001_R1_001 008-HIV-C30U-25c-b-2-p_S8_L001_R1_001
# 009-HIV-C30U-25c-b-3-p_S9_L001_R1_001 009-HIV-C30U-25c-b-3-p_S9_L001_R1_001
# 010-HIV-C30U-25c-b-4-p_S10_L001_R1_001 010-HIV-C30U-25c-b-4-p_S10_L001_R1_001
# 011-HIV-C30U-25c-b-5-p_S11_L001_R1_001 011-HIV-C30U-25c-b-5-p_S11_L001_R1_001
# 012-HIV-C30U-25c-b-6-p_S12_L001_R1_001 012-HIV-C30U-25c-b-6-p_S12_L001_R1_001
# 013-HIV-C30U-70c-a-1-p_S13_L001_R1_001 013-HIV-C30U-70c-a-1-p_S13_L001_R1_001
# 014-HIV-C30U-70c-a-2-p_S14_L001_R1_001 014-HIV-C30U-70c-a-2-p_S14_L001_R1_001
# 015-HIV-C30U-70c-a-3-p_S15_L001_R1_001 015-HIV-C30U-70c-a-3-p_S15_L001_R1_001
# 016-HIV-C30U-70c-a-4-p_S16_L001_R1_001 016-HIV-C30U-70c-a-4-p_S16_L001_R1_001
# 017-HIV-C30U-70c-a-5-p_S17_L001_R1_001 017-HIV-C30U-70c-a-5-p_S17_L001_R1_001
# 018-HIV-C30U-70c-a-6-p_S18_L001_R1_001 018-HIV-C30U-70c-a-6-p_S18_L001_R1_001
# 019-HIV-C30U-70c-b-1-p_S19_L001_R1_001 019-HIV-C30U-70c-b-1-p_S19_L001_R1_001
# 020-HIV-C30U-70c-b-2-p_S20_L001_R1_001 020-HIV-C30U-70c-b-2-p_S20_L001_R1_001
# 021-HIV-C30U-70c-b-3-p_S21_L001_R1_001 021-HIV-C30U-70c-b-3-p_S21_L001_R1_001
# 022-HIV-C30U-70c-b-4-p_S22_L001_R1_001 022-HIV-C30U-70c-b-4-p_S22_L001_R1_001
# 023-HIV-C30U-70c-b-5-p_S23_L001_R1_001 023-HIV-C30U-70c-b-5-p_S23_L001_R1_001
# 024-HIV-C30U-70c-b-6-p_S24_L001_R1_001 024-HIV-C30U-70c-b-6-p_S24_L001_R1_001
# 025-HIV-C30U-75c-a-1-p_S25_L001_R1_001 025-HIV-C30U-75c-a-1-p_S25_L001_R1_001
# 026-HIV-C30U-75c-a-2-p_S26_L001_R1_001 026-HIV-C30U-75c-a-2-p_S26_L001_R1_001
# 027-HIV-C30U-75c-a-3-p_S27_L001_R1_001 027-HIV-C30U-75c-a-3-p_S27_L001_R1_001
# 028-HIV-C30U-75c-a-4-p_S28_L001_R1_001 028-HIV-C30U-75c-a-4-p_S28_L001_R1_001
# 029-HIV-C30U-75c-a-5-p_S29_L001_R1_001 029-HIV-C30U-75c-a-5-p_S29_L001_R1_001
# 030-HIV-C30U-75c-a-6-p_S30_L001_R1_001 030-HIV-C30U-75c-a-6-p_S30_L001_R1_001
# 031-HIV-C30U-75c-b-1-p_S31_L001_R1_001 031-HIV-C30U-75c-b-1-p_S31_L001_R1_001
# 032-HIV-C30U-75c-b-2-p_S32_L001_R1_001 032-HIV-C30U-75c-b-2-p_S32_L001_R1_001
# 033-HIV-C30U-75c-b-3-p_S33_L001_R1_001 033-HIV-C30U-75c-b-3-p_S33_L001_R1_001
# 034-HIV-C30U-75c-b-4-p_S34_L001_R1_001 034-HIV-C30U-75c-b-4-p_S34_L001_R1_001
# 035-HIV-C30U-75c-b-5-p_S35_L001_R1_001 035-HIV-C30U-75c-b-5-p_S35_L001_R1_001
# 036-HIV-C30U-75c-b-6-p_S36_L001_R1_001 036-HIV-C30U-75c-b-6-p_S36_L001_R1_001
# 037-HIV-C30U-80c-a-1-p_S37_L001_R1_001 037-HIV-C30U-80c-a-1-p_S37_L001_R1_001
# 038-HIV-C30U-80c-a-2-p_S38_L001_R1_001 038-HIV-C30U-80c-a-2-p_S38_L001_R1_001
# 039-HIV-C30U-80c-a-3-p_S39_L001_R1_001 039-HIV-C30U-80c-a-3-p_S39_L001_R1_001
# 040-HIV-C30U-80c-a-4-p_S40_L001_R1_001 040-HIV-C30U-80c-a-4-p_S40_L001_R1_001
# 041-HIV-C30U-80c-a-5-p_S41_L001_R1_001 041-HIV-C30U-80c-a-5-p_S41_L001_R1_001
# 042-HIV-C30U-80c-a-6-p_S42_L001_R1_001 042-HIV-C30U-80c-a-6-p_S42_L001_R1_001
# 043-HIV-C30U-80c-b-1-p_S43_L001_R1_001 043-HIV-C30U-80c-b-1-p_S43_L001_R1_001
# 044-HIV-C30U-80c-b-2-p_S44_L001_R1_001 044-HIV-C30U-80c-b-2-p_S44_L001_R1_001
# 045-HIV-C30U-80c-b-3-p_S45_L001_R1_001 045-HIV-C30U-80c-b-3-p_S45_L001_R1_001
# 046-HIV-C30U-80c-b-4-p_S46_L001_R1_001 046-HIV-C30U-80c-b-4-p_S46_L001_R1_001
# 047-HIV-C30U-80c-b-5-p_S47_L001_R1_001 047-HIV-C30U-80c-b-5-p_S47_L001_R1_001
# 048-HIV-C30U-80c-b-6-p_S48_L001_R1_001 048-HIV-C30U-80c-b-6-p_S48_L001_R1_001
# 049-HIV-WT-25c-a-6-m_S49_L001_R1_001 049-HIV-WT-25c-a-6-m_S49_L001_R1_001
# 050-HIV-WT-25c-b-6-m_S50_L001_R1_001 050-HIV-WT-25c-b-6-m_S50_L001_R1_001
# 051-HIV-WT-70c-a-6-m_S51_L001_R1_001 051-HIV-WT-70c-a-6-m_S51_L001_R1_001
# 052-HIV-WT-70c-b-6-m_S52_L001_R1_001 052-HIV-WT-70c-b-6-m_S52_L001_R1_001
# 053-HIV-WT-75c-a-6-m_S53_L001_R1_001 053-HIV-WT-75c-a-6-m_S53_L001_R1_001
# 054-HIV-WT-75c-b-6-m_S54_L001_R1_001 054-HIV-WT-75c-b-6-m_S54_L001_R1_001
# 055-HIV-WT-80c-a-6-m_S55_L001_R1_001 055-HIV-WT-80c-a-6-m_S55_L001_R1_001
# 056-HIV-WT-80c-b-6-m_S56_L001_R1_001 056-HIV-WT-80c-b-6-m_S56_L001_R1_001
# 057-HIV-UUCG-GS-25c-a-6-m_S57_L001_R1_001 057-HIV-UUCG-GS-25c-a-6-m_S57_L001_R1_001
# 058-HIV-UUCG-GS-25c-b-6-m_S58_L001_R1_001 058-HIV-UUCG-GS-25c-b-6-m_S58_L001_R1_001
# 059-HIV-UUCG-GS-70c-a-6-m_S59_L001_R1_001 059-HIV-UUCG-GS-70c-a-6-m_S59_L001_R1_001
# 060-HIV-UUCG-GS-70c-b-6-m_S60_L001_R1_001 060-HIV-UUCG-GS-70c-b-6-m_S60_L001_R1_001
# 061-HIV-UUCG-GS-75c-a-6-m_S61_L001_R1_001 061-HIV-UUCG-GS-75c-a-6-m_S61_L001_R1_001
# 062-HIV-UUCG-GS-75c-b-6-m_S62_L001_R1_001 062-HIV-UUCG-GS-75c-b-6-m_S62_L001_R1_001
# 063-HIV-UUCG-GS-80c-a-6-m_S63_L001_R1_001 063-HIV-UUCG-GS-80c-a-6-m_S63_L001_R1_001
# 064-HIV-UUCG-GS-80c-b-6-m_S64_L001_R1_001 064-HIV-UUCG-GS-80c-b-6-m_S64_L001_R1_001
# 065-HIV-UUCG-ES-25c-a-6-m_S65_L001_R1_001 065-HIV-UUCG-ES-25c-a-6-m_S65_L001_R1_001
# 066-HIV-UUCG-ES-25c-b-6-m_S66_L001_R1_001 066-HIV-UUCG-ES-25c-b-6-m_S66_L001_R1_001
# 067-HIV-UUCG-ES-70c-a-6-m_S67_L001_R1_001 067-HIV-UUCG-ES-70c-a-6-m_S67_L001_R1_001
# 068-HIV-UUCG-ES-70c-b-6-m_S68_L001_R1_001 068-HIV-UUCG-ES-70c-b-6-m_S68_L001_R1_001
# 069-HIV-UUCG-ES-75c-a-6-m_S69_L001_R1_001 069-HIV-UUCG-ES-75c-a-6-m_S69_L001_R1_001
# 070-HIV-UUCG-ES-75c-b-6-m_S70_L001_R1_001 070-HIV-UUCG-ES-75c-b-6-m_S70_L001_R1_001
# 071-HIV-UUCG-ES-80c-a-6-m_S71_L001_R1_001 071-HIV-UUCG-ES-80c-a-6-m_S71_L001_R1_001
# 072-HIV-UUCG-ES-80c-b-6-m_S72_L001_R1_001 072-HIV-UUCG-ES-80c-b-6-m_S72_L001_R1_001
# 073-HIV-A35G-25c-a-6-m_S73_L001_R1_001 073-HIV-A35G-25c-a-6-m_S73_L001_R1_001
# 074-HIV-A35G-25c-b-6-m_S74_L001_R1_001 074-HIV-A35G-25c-b-6-m_S74_L001_R1_001
# 075-HIV-A35G-70c-a-6-m_S75_L001_R1_001 075-HIV-A35G-70c-a-6-m_S75_L001_R1_001
# 076-HIV-A35G-70c-b-6-m_S76_L001_R1_001 076-HIV-A35G-70c-b-6-m_S76_L001_R1_001
# 077-HIV-A35G-75c-a-6-m_S77_L001_R1_001 077-HIV-A35G-75c-a-6-m_S77_L001_R1_001
# 078-HIV-A35G-75c-b-6-m_S78_L001_R1_001 078-HIV-A35G-75c-b-6-m_S78_L001_R1_001
# 079-HIV-A35G-80c-a-6-m_S79_L001_R1_001 079-HIV-A35G-80c-a-6-m_S79_L001_R1_001
# 080-HIV-A35G-80c-b-6-m_S80_L001_R1_001 080-HIV-A35G-80c-b-6-m_S80_L001_R1_001
# 081-HIV-C30U-25c-a-6-m_S81_L001_R1_001 081-HIV-C30U-25c-a-6-m_S81_L001_R1_001
# 082-HIV-C30U-25c-b-6-m_S82_L001_R1_001 082-HIV-C30U-25c-b-6-m_S82_L001_R1_001
# 083-HIV-C30U-70c-a-6-m_S83_L001_R1_001 083-HIV-C30U-70c-a-6-m_S83_L001_R1_001
# 084-HIV-C30U-70c-b-6-m_S84_L001_R1_001 084-HIV-C30U-70c-b-6-m_S84_L001_R1_001
# 085-HIV-C30U-75c-a-6-m_S85_L001_R1_001 085-HIV-C30U-75c-a-6-m_S85_L001_R1_001
# 086-HIV-C30U-75c-b-6-m_S86_L001_R1_001 086-HIV-C30U-75c-b-6-m_S86_L001_R1_001
# 087-HIV-C30U-80c-a-6-m_S87_L001_R1_001 087-HIV-C30U-80c-a-6-m_S87_L001_R1_001
# 088-HIV-C30U-80c-b-6-m_S88_L001_R1_001 088-HIV-C30U-80c-b-6-m_S88_L001_R1_001
#     rxn_group  temperature  replicate  reaction_time  probe_concentration  \
# 105      37_2           37          2             60             0.015853
# 106      37_2           37          2           7200             0.015853
# 107      37_2           37          2           9000             0.015853
# 108      37_2           37          2           1200             0.015853
# 109      37_2           37          2           2400             0.015853
# ..        ...          ...        ...            ...                  ...
# 771      33_1           33          1          11100             0.000000
# 772      80_3           80          3             80             0.000000
# 774      37_5           37          5           7080             0.000000
# 777      33_2           33          2          11100             0.000000
# 778      80_4           80          4             80             0.000000
#
#     probe buffer construct   RT done_by  treated  sequencing_run  \
# 105   dms      6        25  MRT      RB        1              17
# 106   dms      6        25  MRT      RB        1              17
# 107   dms      6        25  MRT      RB        1              17
# 108   dms      6        25  MRT      RB        1              17
# 109   dms      6        25  MRT      RB        1              17
# ..    ...    ...       ...  ...     ...      ...             ...
# 771  etoh      6        25  MRT     EKC        0              33
# 772  etoh      6        25  MRT     EKC        0              33
# 774  etoh      6        25  MRT     EKC        0              33
# 777  etoh      6        25  MRT     EKC        0              33
# 778  etoh      6        25  MRT     EKC        0              33
#
#                                     sample_name  \
# 105          DMS-1-WTII_S2_L001_R1_001.fastq.gz
# 106        DMS-120-WTII_S7_L001_R1_001.fastq.gz
# 107        DMS-150-WTII_S8_L001_R1_001.fastq.gz
# 108         DMS-20-WTII_S3_L001_R1_001.fastq.gz
# 109         DMS-40-WTII_S4_L001_R1_001.fastq.gz
# ..                                          ...
# 771  089_fourU_WT33c_a_6_m_S185_R1_001.fastq.gz
# 772  090_fourU_WT80c_a_6_m_S186_R1_001.fastq.gz
# 774  092_fourU_WT37c_b_6_m_S188_R1_001.fastq.gz
# 777  095_fourU_WT33c_b_6_m_S191_R1_001.fastq.gz
# 778  096_fourU_WT80c_b_6_m_S192_R1_001.fastq.gz
#
#                                                 fq_dir  \
# 105  /projects/b1044/Sequencing/SHAPE-Seq/EKC/22120...
# 106  /projects/b1044/Sequencing/SHAPE-Seq/EKC/22120...
# 107  /projects/b1044/Sequencing/SHAPE-Seq/EKC/22120...
# 108  /projects/b1044/Sequencing/SHAPE-Seq/EKC/22120...
# 109  /projects/b1044/Sequencing/SHAPE-Seq/EKC/22120...
# ..                                                 ...
# 771  /projects/b1044/Sequencing/SHAPE-Seq/EKC/24042...
# 772  /projects/b1044/Sequencing/SHAPE-Seq/EKC/24042...
# 774  /projects/b1044/Sequencing/SHAPE-Seq/EKC/24042...
# 777  /projects/b1044/Sequencing/SHAPE-Seq/EKC/24042...
# 778  /projects/b1044/Sequencing/SHAPE-Seq/EKC/24042...
#
#                          fmod_runs
# 105  fmod_calc_runs_2/000000000258
# 106  fmod_calc_runs_2/000000000263
# 107  fmod_calc_runs_2/000000000264
# 108  fmod_calc_runs_2/000000000259
# 109  fmod_calc_runs_2/000000000260
# ..                             ...
# 771  fmod_calc_runs_2/000000001097
# 772  fmod_calc_runs_2/000000001098
# 774  fmod_calc_runs_2/000000001100
# 777  fmod_calc_runs_2/000000001103
# 778  fmod_calc_runs_2/000000001104
#
# [196 rows x 15 columns]

# %%
def extract_info_from_spats(log_file, config_file, sample_name):
    """
    Extracts information from a spats directory.

    Parameters:
        log_file (str): Path to the ShapeMapper log file.
        sample_name (str): Name of the sample to check against the R1 file.

    Returns:
        tuple: Contains the following elements:
            - run_datetime (str): The datetime when the ShapeMapper run started.
            - version (str): The version of ShapeMapper used.
            - r1_file (str): The R1 file used in the run.
            - untreated (int): Indicates if the sample was untreated (1 if untreated, 0 otherwise).
            - denatured (int): Indicates if the sample was denatured (1 if denatured, 0 otherwise).
            - sample_check (bool): Indicates if the sample name matches the R1 file.
    """

    with open(log_file) as f:
        log_lines = f.readlines()
    
    with open(config_file) as f:
        config_lines = f.readlines()

    # find all lines containing " : run " and get index of most recent one
    detect_spats_runs = [i for i, line in enumerate(log_lines) if ' : run' in line]
    assert len(detect_spats_runs) > 0, 'No spats runs detected in log file'

    most_recent_run = detect_spats_runs[-1]
    log_lines = log_lines[most_recent_run:]

    # check spats success
    # TODO

    #print(log_file)
    # extract date from:  "2022/11/26 11:56 : run, 172.31s"
    run_datetime = log_lines[0].split(' : run')[0]
    version = 'v2.0.5'
    
    # extract run args
    run_args = [i for i, line in enumerate(log_lines) if not line.startswith('#')]
    run_args = '\n'.join(run_args)
    
    # extract R1 file
    r1_lines = [line for line in config_lines if 'r1' in line]
    assert (len(r1_lines) == 1), 'R1 line not found in config file'

    r1_file = r1_lines[0].split('=')[-1]
    r1_file = r1_file.replace(' ', '').rstrip()
    assert (r1_file is not None) or (r1_file == ''), 'R1 file not found in run_args'
    
    # confirm sample_name matches r1_file
    if r1_file.endswith('.fastq.gz'):
        r1_file_check = r1_file[:-9]
    elif r1_file.endswith('.fastq'):
        r1_file_check = r1_file[:-6]
    else:
        r1_file_check = r1_file
    if sample_name.endswith('.fastq.gz'):
        sample_name_check = sample_name[:-9]
    elif sample_name.endswith('.fastq'):
        sample_name_check = sample_name[:-6]
    else:
        sample_name_check = sample_name
    if r1_file.startswith('./'):
        r1_file_check = r1_file_check[2:]

    sample_check = (sample_name_check == r1_file_check)
    
    return run_datetime, version, r1_file, sample_check

# %%
def construct_fmod_calc_run_spats(sample_name, fmod_dir, db_file):

    
    log_file = glob.glob(f'/projects/b1044/Computational_Output/EKC/{fmod_dir}/**/spats.log', recursive = True)[0]
    config_file = glob.glob(f'/projects/b1044/Computational_Output/EKC/{fmod_dir}/**/spats.config', recursive = True)[0]
    run_datetime, version, r1_file, sample_check = extract_info_from_spats(log_file, config_file, sample_name)
    s_id = fetch_s_id(db_file, sample_name)

    # get potential fmod_calc id but do not add until fmod vals are good

    # Tentative fmod_calc id (pending fmod_vals check)
    fmod_calc_id = get_max_id(db_file, 'fmod_calc_runs', 'id')

    profile_txt = glob.glob(f'/projects/b1044/Computational_Output/EKC/{fmod_dir}/**/*.csv', recursive=True)
    # exclude reads.csv
    profile_txt = [x for x in profile_txt if 'reads' not in x]
    
    # choose profile with "reanalyzed"
    if len(profile_txt) > 1:
        profile_txt = [x for x in profile_txt if 'reanalyzed' in x]
        #print(fmod_dir, profile_txt)
    assert len(profile_txt) == 1, 'Multiple or no profile.txt files found'
    profile_txt = profile_txt[0]

    return run_datetime, version, r1_file, sample_check, s_id, fmod_calc_id, profile_txt


def construct_fmod_vals_spats(profile_txt, db_file, s_id, fmod_calc_id):
    # read the csv file
    df = pd.read_csv(profile_txt)
    read_depth = df.iloc[0, 3]#['f+']
    df = df.iloc[1:, :]

    seq_from_profile = ''.join(df['nt'].values)
    dict_convertTU = {'T': 'U', 't': 'u'}
    seq_from_profile = ''.join([dict_convertTU.get(base, base) for base in seq_from_profile])
    
    construct_seq = fetch_construct_seq(db_file, s_id)
    assert construct_seq.upper() == seq_from_profile.upper(), 'Construct sequence does not match spats out.csv sequence'

    nt_ids, nt_seq = fetch_nt_ids(db_file, s_id)
    assert nt_seq.upper() == seq_from_profile.upper(), 'Nt sequence does not match profile.txt sequence'

    rxn_id, rxn_treated = fetch_rxn_id(db_file, s_id)

    fmod_vals_df = pd.DataFrame({'nt_id': nt_ids, 'fmod_calc_run_id': fmod_calc_id, 'fmod_val': df['beta'], 'valtype': 'beta', 'read_depth': read_depth, 'rxn_id': rxn_id})
    return fmod_vals_df

# %%
samples = pd.read_csv('/projects/b1044/Computational_Output/EKC/EKC.01_SHAPE_standardization/EKC.01.060.developing_DB_input/samples_import.csv')

i = 5
# check if sample_name column has not repeats
fmod_dir = samples[samples['RT'] == 'SSIII']['fmod_runs'].values[i]
sample_name = samples[samples['RT'] == 'SSIII']['sample_name'].values[i]

# get text inside single quote '
if "'" in fmod_dir:
    fmod_dir = fmod_dir.split("'")[1]
print(fmod_dir)
print(sample_name)
db_file = '/projects/b1044/Computational_Output/EKC/EKC.01_SHAPE_standardization/EKC.01.060.developing_DB_input/new.db'
try:
    run_datetime, version, r1_file, sample_check, s_id, fmod_calc_id, profile_txt = construct_fmod_calc_run_spats(sample_name, fmod_dir, db_file)
except:
     print('Error in log file, skipping...')
if sample_check:
     fmod_vals_df = construct_fmod_vals_spats(profile_txt, db_file, s_id, fmod_calc_id)
else:
     print('Sample name does not match R1 file, skipping...')
# Out:
# fmod_calc_runs_2/000000000189
# 006-EKC-fourUnew-WT-II-37C-dms-stop-90_S6_L001_R1_001.fastq.gz
# Error in log file, skipping...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [204], in <cell line: 18>()
#      17      print('Error in log file, skipping...')
#      18 if sample_check:
# ---> 19      fmod_vals_df = construct_fmod_vals_spats(profile_txt, db_file, s_id, fmod_calc_id)
#      20 else:
#      21      print('Sample name does not match R1 file, skipping...')
#
# Input In [203], in construct_fmod_vals_spats(profile_txt, db_file, s_id, fmod_calc_id)
#      28 def construct_fmod_vals_spats(profile_txt, db_file, s_id, fmod_calc_id):
#      29     # read the csv file
#      30     df = pd.read_csv(profile_txt)
# ---> 31     read_depth = df.iloc[0, 3]#['f+']
#      32     df = df.iloc[1:, :]
#      34     seq_from_profile = ''.join(df['nt'].values)
#
# File ~/.conda/envs/nupack/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1066     if self._is_scalar_access(key):
# -> 1067         return self.obj._get_value(*key, takeable=self._takeable)
#    1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#
# File ~/.conda/envs/nupack/lib/python3.10/site-packages/pandas/core/frame.py:3912, in DataFrame._get_value(self, index, col, takeable)
#    3893 """
#    3894 Quickly retrieve single value at passed column and index.
#    3895
#    (...)
#    3909 `self.columns._index_as_unique`; Caller is responsible for checking.
#    3910 """
#    3911 if takeable:
# -> 3912     series = self._ixs(col, axis=1)
#    3913     return series._values[index]
#    3915 series = self._get_item_cache(col)
#
# File ~/.conda/envs/nupack/lib/python3.10/site-packages/pandas/core/frame.py:3726, in DataFrame._ixs(self, i, axis)
#    3722     return result
#    3724 # icol
#    3725 else:
# -> 3726     label = self.columns[i]
#    3728     col_mgr = self._mgr.iget(i)
#    3729     result = self._box_col_values(col_mgr, i)
#
# File ~/.conda/envs/nupack/lib/python3.10/site-packages/pandas/core/indexes/base.py:5358, in Index.__getitem__(self, key)
#    5355 if is_integer(key) or is_float(key):
#    5356     # GH#44051 exclude bool, which would return a 2d ndarray
#    5357     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5358     return getitem(key)
#    5360 if isinstance(key, slice):
#    5361     # This case is separated from the conditional above to avoid
#    5362     # pessimization com.is_bool_indexer and ndim checks.
#    5363     result = getitem(key)
#
# IndexError: index 3 is out of bounds for axis 0 with size 1

# %%
ssiii_only = samples[~((samples['RT'] == 'MRT') | (samples['RT'] == 'MRTpH9'))]
# drop nan values 
ssiii_only = ssiii_only.dropna(subset=['fmod_runs'])

for i, row in ssiii_only.iterrows():
    fmod_dir = row['fmod_runs']
    sample_name = row['sample_name']

    # get text inside single quote '
    if "'" in fmod_dir:
        fmod_dir = fmod_dir.split("'")[1]
    #print(fmod_dir)
    #print(sample_name)
    
    try:
        run_datetime, version, r1_file, sample_check, s_id, fmod_calc_id, profile_txt = construct_fmod_calc_run_spats(sample_name, fmod_dir, db_file)
    except:
        print('---------------------------------------------')
        print(sample_name)
        traceback.print_exc()
        print('---------------------------------------------')
        continue

    if sample_check:
        fmod_vals_df = construct_fmod_vals_spats(profile_txt, db_file, s_id, fmod_calc_id)
    else:
        print(fmod_dir, r1_file, sample_name)
        print('Sample name does not match R1 file, skipping...')
        continue
    
    # simulate processed by dropping row
    ssiii_only = ssiii_only.drop(index=i)
    
ssiii_only
# Out:
# Empty DataFrame
# Columns: [rxn_group, temperature, replicate, reaction_time, probe_concentration, probe, buffer, construct, RT, done_by, treated, sequencing_run, sample_name, fq_dir, fmod_runs]
# Index: []

# %%
import subprocess

# mv from src to dest

def move_directory_unix(src_dir, dest_dir):
    # mv automatically handles directories and their contents without the need for -r
    subprocess.run(['mv', src_dir, dest_dir], check=True)
    print(f"Moved {src_dir} to {dest_dir} using mv command")

for i, row in df.iterrows():
    move_directory_unix(row['src_dir'], row['dest_dir'])
