# %%
import sqlite3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import matplotlib as mpl

# set font to 15
mpl.rcParams.update({'font.size': 8})

# Set Helvetica font globally
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = ['Helvetica']

# Optional: make sure fonts are updated
mpl.rcParams['pdf.fonttype'] = 42  # Avoids Type 3 fonts in PDF output
mpl.rcParams['ps.fonttype'] = 42

# %%
nerd_sqlite = '../../Core_nerd_analysis/nerd.sqlite'
rg_ids = [123, 124, 129, 130]  # update if needed

conn = sqlite3.connect(nerd_sqlite)
conn.row_factory = sqlite3.Row

query = """
SELECT *
FROM probe_tc_fits_view
WHERE fit_kind = 'round3_constrained'
  AND rg_id IN ({})
  AND rt_protocol = 'MRT'
ORDER BY rg_id
""".format(",".join(["?"] * len(rg_ids)))

df = pd.read_sql_query(query, conn, params=rg_ids)
conn.close()
df
# Out:
#      fit_run_id  rg_id  nt_id            fit_kind rg_label  temperature probe  \
# 0        274536    123    797  round3_constrained        1         23.0  etoh
# 1        274537    123    798  round3_constrained        1         23.0  etoh
# 2        274538    123    799  round3_constrained        1         23.0  etoh
# 3        274539    123    800  round3_constrained        1         23.0  etoh
# 4        274540    123    801  round3_constrained        1         23.0  etoh
# ..          ...    ...    ...                 ...      ...          ...   ...
# 411      275511    124    939  round3_constrained        2         23.0  etoh
# 412      275516    124    944  round3_constrained        2         23.0  etoh
# 413      275517    124    945  round3_constrained        2         23.0  etoh
# 414      275520    124    948  round3_constrained        2         23.0  etoh
# 415      275523    124    951  round3_constrained        2         23.0  etoh
#
#      probe_conc rt_protocol  buffer_id  ...        buffer_name nt_site  \
# 0      0.015853         MRT          2  ...   P4P6_bicine_NoMg     103
# 1      0.015853         MRT          2  ...   P4P6_bicine_NoMg     104
# 2      0.015853         MRT          2  ...   P4P6_bicine_NoMg     105
# 3      0.015853         MRT          2  ...   P4P6_bicine_NoMg     106
# 4      0.015853         MRT          2  ...   P4P6_bicine_NoMg     107
# ..          ...         ...        ...  ...                ...     ...
# 411    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     245
# 412    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     250
# 413    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     251
# 414    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     254
# 415    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     257
#
#     nt_base      kobs  log_kobs  log_kdeg  log_kobs_err  log_kdeg_err  \
# 0         G  0.000660 -7.323764 -8.067974      0.296183           0.0
# 1         A  0.022931 -3.775280 -8.067974      0.039808           0.0
# 2         A  0.017473 -4.047125 -8.067974      0.045539           0.0
# 3         U  0.000927 -6.983541 -8.067974      0.267403           0.0
# 4         U  0.001103 -6.809645 -8.067974      0.144518           0.0
# ..      ...       ...       ...       ...           ...           ...
# 411       G  0.000381 -7.873467 -8.242844      0.577642           0.0
# 412       G  0.000255 -8.273244 -8.242844      1.030822           0.0
# 413       G  0.000253 -8.280811 -8.242844      1.323388           0.0
# 414       G  0.000547 -7.510987 -8.242844      0.923467           0.0
# 415       G  0.000658 -7.326576 -8.242844      0.561482           0.0
#
#            r2                                      metadata_json
# 0    0.487337  {"base": "G", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# 1    0.981779  {"base": "A", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# 2    0.976153  {"base": "A", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# 3    0.538394  {"base": "U", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# 4    0.799772  {"base": "U", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# ..        ...                                                ...
# 411  0.374830  {"base": "G", "fmod_run_ids": [44, 45, 46, 47,...
# 412  0.158407  {"base": "G", "fmod_run_ids": [44, 45, 46, 47,...
# 413  0.102497  {"base": "G", "fmod_run_ids": [44, 45, 46, 47,...
# 414  0.190010  {"base": "G", "fmod_run_ids": [44, 45, 46, 47,...
# 415  0.388272  {"base": "G", "fmod_run_ids": [44, 45, 46, 47,...
#
# [416 rows x 22 columns]

# %%
import numpy as np

def calculate_dG(logkobs, logkadd):
    R = 1.9872036e-3  # kcal/(mol*K)
    T = 298.15  # K
    
    logKKp1 = logkobs - logkadd
    KKp1 = np.exp(logKKp1) # K / (K+1)
    K = KKp1 / (1 - KKp1)
    dG = -R * T * np.log(K)

    return dG

logkadd = -2.676278119425211 # logkadd
logkobs_r2_99 = -3.4806204679354953
logkobs_r2_55 = -7.240355294404981
logkobs_r2_39 = -7.503658411920693

dG_r2_99 = calculate_dG(logkobs_r2_99, logkadd)
dG_r2_55 = calculate_dG(logkobs_r2_55, logkadd)
dG_r2_39 = calculate_dG(logkobs_r2_39, logkadd)

print(f"dG for r2=0.99: {dG_r2_99:.2f} kcal/mol")
print(f"dG for r2=0.55: {dG_r2_55:.2f} kcal/mol")
print(f"dG for r2=0.39: {dG_r2_39:.2f} kcal/mol")
# Out:
# dG for r2=0.99: 0.13 kcal/mol
# dG for r2=0.55: 2.70 kcal/mol
# dG for r2=0.39: 2.86 kcal/mol

# %%
# filter to nt_base = C
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

df_c = df[df['nt_base'] == 'C']

fig, ax = plt.subplots(figsize=(2, 2))

# Main scatter plot
sns.scatterplot(data=df_c, x='log_kobs', y='r2', color = 'black', size = 1, ax=ax)
# set main axes labels

# draw horizontal line at r2 = 0.50
ax.axhline(0.50, color='red', linestyle='--', linewidth=1)
ax.set_xlabel(r'$\log(k_{obs})$')
ax.set_ylabel(r'$R^2$')


# set xlim -15 to -2
ax.set_xlim(-15, -2)
ax.set_ylim(0, 1)

# remove legend
ax.legend().remove()

plt.tight_layout()
plt.savefig("r2_v_log_kobs_p4p6_C.pdf")
plt.show()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp

# %%
df_c
# Out:
#      fit_run_id  rg_id  nt_id            fit_kind rg_label  temperature probe  \
# 6        274542    123    803  round3_constrained        1         23.0  etoh
# 18       274554    123    815  round3_constrained        1         23.0  etoh
# 21       274557    123    818  round3_constrained        1         23.0  etoh
# 24       274560    123    821  round3_constrained        1         23.0  etoh
# 25       274561    123    822  round3_constrained        1         23.0  etoh
# ..          ...    ...    ...                 ...      ...          ...   ...
# 345      275340    124    934  round3_constrained        2         23.0  etoh
# 360      275355    124    949  round3_constrained        2         23.0  etoh
# 365      275360    124    954  round3_constrained        2         23.0  etoh
# 368      275363    124    957  round3_constrained        2         23.0  etoh
# 369      275364    124    958  round3_constrained        2         23.0  etoh
#
#      probe_conc rt_protocol  buffer_id  ...        buffer_name nt_site  \
# 6      0.015853         MRT          2  ...   P4P6_bicine_NoMg     109
# 18     0.015853         MRT          2  ...   P4P6_bicine_NoMg     121
# 21     0.015853         MRT          2  ...   P4P6_bicine_NoMg     124
# 24     0.015853         MRT          2  ...   P4P6_bicine_NoMg     127
# 25     0.015853         MRT          2  ...   P4P6_bicine_NoMg     128
# ..          ...         ...        ...  ...                ...     ...
# 345    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     240
# 360    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     255
# 365    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     260
# 368    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     263
# 369    0.015853         MRT          3  ...  P4P6_bicine_5mMMg     264
#
#     nt_base      kobs  log_kobs  log_kdeg  log_kobs_err  log_kdeg_err  \
# 6         C  0.012702 -4.365995 -8.067974      0.035195           0.0
# 18        C  0.006395 -5.052206 -8.067974      0.053141           0.0
# 21        C  0.054657 -2.906675 -8.067974      0.020932           0.0
# 24        C  0.001241 -6.691844 -8.067974      0.124173           0.0
# 25        C  0.001296 -6.648599 -8.067974      0.062301           0.0
# ..      ...       ...       ...       ...           ...           ...
# 345       C  0.000254 -8.277625 -8.242844      0.971599           0.0
# 360       C  0.009006 -4.709859 -8.242844      0.116306           0.0
# 365       C  0.002224 -6.108494 -8.242844      0.291251           0.0
# 368       C  0.001841 -6.297629 -8.242844      0.260076           0.0
# 369       C  0.000440 -7.729585 -8.242844      0.572844           0.0
#
#            r2                                      metadata_json
# 6    0.985545  {"base": "C", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# 18   0.967432  {"base": "C", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# 21   0.995063  {"base": "C", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# 24   0.844031  {"base": "C", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# 25   0.955552  {"base": "C", "fmod_run_ids": [1, 2, 3, 4, 5, ...
# ..        ...                                                ...
# 345  0.174845  {"base": "C", "fmod_run_ids": [44, 45, 46, 47,...
# 360  0.937200  {"base": "C", "fmod_run_ids": [44, 45, 46, 47,...
# 365  0.702658  {"base": "C", "fmod_run_ids": [44, 45, 46, 47,...
# 368  0.747605  {"base": "C", "fmod_run_ids": [44, 45, 46, 47,...
# 369  0.378754  {"base": "C", "fmod_run_ids": [44, 45, 46, 47,...
#
# [70 rows x 22 columns]

# %%
# count of points with r2 >= 0.50
total_dfc = len(df_c)
count_r2_ge_50 = df_c[df_c['r2'] >= 0.50].shape[0]
print(f"Count of points with R^2 >= 0.50: {count_r2_ge_50}")
print(f"Total points: {total_dfc}")
print(f"Fraction of points with R^2 >= 0.50: {count_r2_ge_50 / total_dfc:.2f}")
# Out:
# Count of points with R^2 >= 0.50: 48
# Total points: 70
# Fraction of points with R^2 >= 0.50: 0.69

# %%
df_a = df[df['nt_base'] == 'A']
total_dfa = len(df_a)
count_r2_ge_50_a = df_a[df_a['r2'] >= 0.50].shape[0]
print(f"Count of points with R^2 >= 0.50 (A): {count_r2_ge_50_a}")
print(f"Total points (A): {total_dfa}")
print(f"Fraction of points with R^2 >= 0.50 (A): {count_r2_ge_50_a / total_dfa:.2f}")
# Out:
# Count of points with R^2 >= 0.50 (A): 98
# Total points (A): 98
# Fraction of points with R^2 >= 0.50 (A): 1.00

# %%
# filter to nt_base = C
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

df_c = df[df['nt_base'] == 'A']

fig, ax = plt.subplots(figsize=(2, 2))

# Main scatter plot
sns.scatterplot(data=df_c, x='log_kobs', y='r2', color = 'black', size = 1, ax=ax)
# set main axes labels

# draw horizontal line at r2 = 0.50
ax.axhline(0.50, color='red', linestyle='--', linewidth=1)
ax.set_xlabel(r'$\log(k_{obs})$')
ax.set_ylabel(r'$R^2$')


# set xlim -15 to -2
ax.set_xlim(-15, -2)
ax.set_ylim(0, 1)

# remove legend
ax.legend().remove()

plt.tight_layout()
plt.savefig("r2_v_log_kobs_p4p6_A.pdf")
plt.show()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
