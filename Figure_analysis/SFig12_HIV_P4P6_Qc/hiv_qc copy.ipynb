# %%
import sqlite3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import matplotlib as mpl

# set font to 15
mpl.rcParams.update({'font.size': 8})

# Set Helvetica font globally
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = ['Helvetica']

# Optional: make sure fonts are updated
mpl.rcParams['pdf.fonttype'] = 42  # Avoids Type 3 fonts in PDF output
mpl.rcParams['ps.fonttype'] = 42

# %%
    - 107
    - 108
    - 109 
    - 110
    - 111
    - 112
    - 113
    - 114
    - 115
    - 116 
    - 117
    - 118
    - 119
    - 120
    - 121 # G detect just noisier
    - 122
    - 91
    - 92
    - 93
    - 94
    - 95
    - 96
    - 97
    - 98
      - 83
      - 84
      - 85
        - 86
      - 87
      - 88
      - 89
      - 90

# %%
nerd_sqlite = '../../Core_nerd_analysis/nerd.sqlite'
rg_ids = [
    107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120,
    121,  # G detect just noisier
    122,
    91, 92, 93, 94, 95, 96, 97, 98,
    83, 84, 85, 86, 87, 88, 89, 90,
]

conn = sqlite3.connect(nerd_sqlite)
conn.row_factory = sqlite3.Row

query = """
SELECT *
FROM probe_tc_fits_view
WHERE fit_kind = 'round3_constrained'
  AND rg_id IN ({})
  AND rt_protocol = 'MRT'
ORDER BY rg_id
""".format(",".join(["?"] * len(rg_ids)))

df = pd.read_sql_query(query, conn, params=rg_ids)
conn.close()
df
# Out:
#       fit_run_id  rg_id  nt_id            fit_kind rg_label  temperature  \
# 0         262562     83    319  round3_constrained  25_1_15         25.0
# 1         262563     83    320  round3_constrained  25_1_15         25.0
# 2         262564     83    321  round3_constrained  25_1_15         25.0
# 3         262565     83    322  round3_constrained  25_1_15         25.0
# 4         262566     83    323  round3_constrained  25_1_15         25.0
# ...          ...    ...    ...                 ...      ...          ...
# 1187      248631    122    111  round3_constrained  80_2_12         80.0
# 1188      248632    122    112  round3_constrained  80_2_12         80.0
# 1189      248633    122    113  round3_constrained  80_2_12         80.0
# 1190      248635    122    115  round3_constrained  80_2_12         80.0
# 1191      248642    122    122  round3_constrained  80_2_12         80.0
#
#      probe  probe_conc rt_protocol  buffer_id  ...               buffer_name  \
# 0     etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
# 1     etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
# 2     etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
# 3     etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
# 4     etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
# ...    ...         ...         ...        ...  ...                       ...
# 1187  etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
# 1188  etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
# 1189  etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
# 1190  etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
# 1191  etoh    0.015853         MRT          4  ...  AlHashimiLab_NMR_NoMg_v2
#
#      nt_site nt_base      kobs  log_kobs  log_kdeg  log_kobs_err  \
# 0         18       G  0.001892 -6.270161 -8.106551      0.426642
# 1         19       C  0.002646 -5.934708 -8.106551      0.341804
# 2         20       A  0.006895 -4.976919 -8.106551      0.039855
# 3         21       G  0.001008 -6.899641 -8.106551      0.324725
# 4         22       A  0.020764 -3.874520 -8.106551      0.076373
# ...      ...     ...       ...       ...       ...           ...
# 1187      32       G  0.001008 -6.899485 -2.886596      0.140019
# 1188      33       G  0.001435 -6.546259 -2.886596      0.149163
# 1189      34       G  0.001232 -6.699061 -2.886596      0.184688
# 1190      36       G  0.002123 -6.154950 -2.886596      0.148678
# 1191      43       G  0.002043 -6.193207 -2.886596      0.098499
#
#       log_kdeg_err        r2  \
# 0              0.0  0.579274
# 1              0.0  0.682251
# 2              0.0  0.993741
# 3              0.0  0.703600
# 4              0.0  0.977767
# ...            ...       ...
# 1187           0.0  0.910808
# 1188           0.0  0.900025
# 1189           0.0  0.854464
# 1190           0.0  0.900671
# 1191           0.0  0.953827
#
#                                           metadata_json
# 0     {"base": "G", "fmod_run_ids": [107, 108, 109, ...
# 1     {"base": "C", "fmod_run_ids": [107, 108, 109, ...
# 2     {"base": "A", "fmod_run_ids": [107, 108, 109, ...
# 3     {"base": "G", "fmod_run_ids": [107, 108, 109, ...
# 4     {"base": "A", "fmod_run_ids": [107, 108, 109, ...
# ...                                                 ...
# 1187  {"base": "G", "fmod_run_ids": [912, 913, 914, ...
# 1188  {"base": "G", "fmod_run_ids": [912, 913, 914, ...
# 1189  {"base": "G", "fmod_run_ids": [912, 913, 914, ...
# 1190  {"base": "G", "fmod_run_ids": [912, 913, 914, ...
# 1191  {"base": "G", "fmod_run_ids": [912, 913, 914, ...
#
# [1192 rows x 22 columns]

# %%
import numpy as np

def calculate_dG(logkobs, logkadd):
    R = 1.9872036e-3  # kcal/(mol*K)
    T = 298.15  # K
    
    logKKp1 = logkobs - logkadd
    KKp1 = np.exp(logKKp1) # K / (K+1)
    K = KKp1 / (1 - KKp1)
    dG = -R * T * np.log(K)

    return dG

logkadd = -2.676278119425211 # logkadd
logkobs_r2_99 = -3.4806204679354953
logkobs_r2_55 = -7.240355294404981
logkobs_r2_39 = -7.503658411920693

dG_r2_99 = calculate_dG(logkobs_r2_99, logkadd)
dG_r2_55 = calculate_dG(logkobs_r2_55, logkadd)
dG_r2_39 = calculate_dG(logkobs_r2_39, logkadd)

print(f"dG for r2=0.99: {dG_r2_99:.2f} kcal/mol")
print(f"dG for r2=0.55: {dG_r2_55:.2f} kcal/mol")
print(f"dG for r2=0.39: {dG_r2_39:.2f} kcal/mol")
# Out:
# dG for r2=0.99: 0.13 kcal/mol
# dG for r2=0.55: 2.70 kcal/mol
# dG for r2=0.39: 2.86 kcal/mol

# %%
# filter to nt_base = C
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

df_c = df[df['nt_base'] == 'C']

fig, ax = plt.subplots(figsize=(2, 2))

# Main scatter plot
sns.scatterplot(data=df_c, x='log_kobs', y='r2', color = 'black', size = 1, ax=ax)
# set main axes labels

# draw horizontal line at r2 = 0.50
ax.axhline(0.50, color='red', linestyle='--', linewidth=1)
ax.set_xlabel(r'$\log(k_{obs})$')
ax.set_ylabel(r'$R^2$')


# set xlim -15 to -2
ax.set_xlim(-15, -2)
ax.set_ylim(0, 1)

# remove legend
ax.legend().remove()

plt.tight_layout()
plt.savefig("r2_v_log_kobs_hiv_C.pdf")
plt.show()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp

# %%
# count of points with r2 >= 0.50
total_dfc = len(df_c)
count_r2_ge_50 = df_c[df_c['r2'] >= 0.50].shape[0]
print(f"Count of points with R^2 >= 0.50: {count_r2_ge_50}")
print(f"Total points: {total_dfc}")
print(f"Fraction of points with R^2 >= 0.50: {count_r2_ge_50 / total_dfc:.2f}")
# Out:
# Count of points with R^2 >= 0.50: 235
# Total points: 280
# Fraction of points with R^2 >= 0.50: 0.84

# %%
df_a = df[df['nt_base'] == 'A']
total_dfa = len(df_a)
count_r2_ge_50_a = df_a[df_a['r2'] >= 0.50].shape[0]
print(f"Count of points with R^2 >= 0.50 (A): {count_r2_ge_50_a}")
print(f"Total points (A): {total_dfa}")
print(f"Fraction of points with R^2 >= 0.50 (A): {count_r2_ge_50_a / total_dfa:.2f}")
# Out:
# Count of points with R^2 >= 0.50 (A): 144
# Total points (A): 144
# Fraction of points with R^2 >= 0.50 (A): 1.00

# %%
# filter to nt_base = C
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

df_c = df[df['nt_base'] == 'A']

fig, ax = plt.subplots(figsize=(2, 2))

# Main scatter plot
sns.scatterplot(data=df_c, x='log_kobs', y='r2', color = 'black', size = 1, ax=ax)
# set main axes labels

# draw horizontal line at r2 = 0.50
ax.axhline(0.50, color='red', linestyle='--', linewidth=1)
ax.set_xlabel(r'$\log(k_{obs})$')
ax.set_ylabel(r'$R^2$')


# set xlim -15 to -2
ax.set_xlim(-15, -2)
ax.set_ylim(0, 1)

# remove legend
ax.legend().remove()

plt.tight_layout()
plt.savefig("r2_v_log_kobs_hiv_A.pdf")
plt.show()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
